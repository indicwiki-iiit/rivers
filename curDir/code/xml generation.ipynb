# %%
import string
from hashlib import sha1
from datetime import datetime
import pandas as pd
from jinja2 import Environment, FileSystemLoader,Template
## Change below siteinfo if different website is picked ##
tewiki = '''<mediawiki xmlns="http://www.mediawiki.org/xml/export-0.10/" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.mediawiki.org/xml/export-0.10/ http://www.mediawiki.org/xml/export-0.10.xsd" version="0.10" xml:lang="te">
    <siteinfo>
        <sitename>tewiki</sitename>
        <dbname>indicwiki</dbname>
        <base>https://tewiki.iiit.ac.in/index.php/%E0%B0%AE%E0%B1%8A%E0%B0%A6%E0%B0%9F%E0%B0%BF_%E0%B0%AA%E0%B1%87%E0%B0%9C%E0%B1%80</base>
        <generator>MediaWiki 1.34.0</generator>
        <case>first-letter</case>
        <namespaces>
            <namespace key="-2" case="first-letter">మీడియా</namespace>
            <namespace key="-1" case="first-letter">ప్రత్యేక</namespace>
            <namespace key="0" case="first-letter" />
            <namespace key="1" case="first-letter">చర్చ</namespace>
            <namespace key="2" case="first-letter">వాడుకరి</namespace>
            <namespace key="3" case="first-letter">వాడుకరి చర్చ</namespace>
            <namespace key="4" case="first-letter">Project</namespace>
            <namespace key="5" case="first-letter">Project చర్చ</namespace>
            <namespace key="6" case="first-letter">దస్త్రం</namespace>
            <namespace key="7" case="first-letter">దస్త్రంపై చర్చ</namespace>
            <namespace key="8" case="first-letter">మీడియావికీ</namespace>
            <namespace key="9" case="first-letter">మీడియావికీ చర్చ</namespace>
            <namespace key="10" case="first-letter">మూస</namespace>
            <namespace key="11" case="first-letter">మూస చర్చ</namespace>
            <namespace key="12" case="first-letter">సహాయం</namespace>
            <namespace key="13" case="first-letter">సహాయం చర్చ</namespace>
            <namespace key="14" case="first-letter">వర్గం</namespace>
            <namespace key="15" case="first-letter">వర్గం చర్చ</namespace>
            <namespace key="828" case="first-letter">మాడ్యూల్</namespace>
            <namespace key="829" case="first-letter">మాడ్యూల్ చర్చ</namespace>
            <namespace key="2300" case="first-letter">Gadget</namespace>
            <namespace key="2301" case="first-letter">Gadget talk</namespace>
            <namespace key="2302" case="case-sensitive">Gadget definition</namespace>
            <namespace key="2303" case="case-sensitive">Gadget definition talk</namespace>
            <namespace key="2600" case="first-letter">Topic</namespace>
        </namespaces>
    </siteinfo>\n'''

# 300000 - 350000 => school's articles
# Global Variables
page_id = 200001

user_id = "19053"
username ="Divyareddy"

# Funtions to write page to file object
def sha36(page_id):
    page_id = str(page_id).encode('utf-8')
    sha16 =sha1(page_id).hexdigest()
    sha10 =int(sha16, 16)

    chars =[]
    alphabets = string.digits +string.ascii_lowercase
    while sha10>0:
        sha10, r = divmod(sha10, 36)
        chars.append(alphabets[r])
    
    return ''.join(reversed(chars))

def writePage(title, wikiText, fobj):
    global user_id, username

    pglen = len(wikiText)
    time =datetime.now().strftime("%Y-%m-%dT%H-%M-%SZ")
    
    curPage ='''\n\n
    <page>
        <title>''' +title +'''</title>
        <ns>0</ns>
        <id>''' +str(page_id) +'''</id>
        <revision>
            <id>''' +str(page_id) +'''</id>
            <timestamp>'''+time+'''</timestamp>
            <contributor>
                <username>''' +username +'''</username>
                <id>''' +str(user_id) +'''</id>
            </contributor>
            <comment>xmlpage created</comment>
            <model>wikitext</model>
            <format>text/x-wiki</format>
            <text xml:space="preserve" bytes="''' +str(pglen) +'''">
            \n''' +wikiText +'''
            </text>
            <sha1>''' +sha36(page_id) +'''</sha1>
        </revision>
    </page>
    \n\n'''

    fobj.write(curPage)
    return


def getData(row):
  title = row['rivername']
  data = row.to_dict('index')
  print(data[i])
  return data[i]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_loader = FileSystemLoader('')
env = Environment(loader=file_loader)
template = env.get_template('Rivers_template_f - Copy.j2')
data = pd.read_excel('/content/drive/MyDrive/rivers mergedata final.xlsx').astype('str') 
ids = data['rivername'].tolist()
print(ids)
fobj = open(f'sample.xml', 'w')
fobj.write(tewiki+'\n')
for i, Id in enumerate(ids):
  row = data.loc[data['rivername']==Id]
  title = row['rivername'].values[0]
  text =template.render(getData(row))
  print(text)
  writePage(title, text, fobj)
  print('\n', i, title)

fobj.write('</mediawiki>')
fobj.close()
# Out:
# Streaming output truncated to the last 5000 lines.
# ==నది ప్రవాహం==
#
# మెకొంగ్ నది చైనా, మయన్మార్, లావోస్, థాయిలాండ్, కంబోడియా, వియత్నాంలోని లసైగోంగ్మా స్ప్రింగ్లోని మౌంట్ గుజోంగ్ముచా , జాడోయి, యుషు టిబెటన్ అటానమస్ ప్రిఫెక్చర్, కింగ్హై, చైనా దగ్గర మొదలవుతుంది.<ref name="dbpedia_link" />ఈ నది మూలం ఎత్తు 5,224 మీటర్లు (17,139 అడుగులు).<ref name="wiki_link" />మెకొంగ్ నది వియత్నాం దగ్గర [[మెకాంగ్ డెల్టా]]లో కలుస్తుంది.<ref name="dbpedia_link" />ఈ నది 0 మీటర్లు (0 అడుగులు) ఎత్తునుంచి సముద్రంలో కలుస్తుంది.<ref name="wiki_link" />
#
# ==సముద్రంలో నీటి విడుదల==
#
# మెకొంగ్ నది మెకాంగ్ డెల్టా, దక్షిణ చైనా సముద్రం వద్ద సముద్రంలో కలుస్తుంది.<ref name="dbpedia_link" />ఈ నది లోని నీరు క్షణముకు సగటు 16,000 ఘనపు మీటర్/సెకండ్ (570,000 ఘనపు అడుగులు/సెకండ్). <ref name="wiki_link" />ఇప్పటి వరకు నమోదు అయినా గరిష్ట మోతాదు క్షణముకు 39,000 క్యూబిక్ మీటర్లు (1,400,000 క్యూబిక్ అడుగులు).<ref name="wiki_link" />ఇప్పటి వరకు నమోదు అయినా కనిష్ట మోతాదు క్షణముకు 1400 క్యూబిక్ మీటర్లు (49000 క్యూబిక్ అడుగులు).<ref name="wiki_link" />
# ==మూలాలు==
# <references />
#
# [[వర్గం:నదులు]][[వర్గం:https://en.wikipedia.org/wiki/Mekongనదులు]]
#  [[వర్గం:http://dbpedia.org/resource/Mekongనదులు]]
#
#
# [[వర్గం:తెవికీ నదులు]]
#
#  97 మెకొంగ్
# {'river_name': 'Segre ', 'rivername': 'సెగ్రే', 'length': '265.0', 'mouthplace - eng': 'Ebro', 'mouthplace': 'ఈబ్రో', 'rivermouth - eng': 'nan', 'mouth': 'nan', 'mouthlocation - eng': 'Ebro', 'mouthlocation': 'ఈబ్రో', 'source1Location - eng': 'Pyrenees', 'source1location': 'పైరినీస్', 'geometry - eng': 'POINT(2.1086111068726 42.402221679688)', 'latitude': '42.4022', 'longitude': '2.10861', 'subdivision - eng': ', Spain, Andorra, France', 'discharge1Location - eng': 'nan', 'discharge_location': 'nan', 'tributariesLeft - eng': 'nan', 'tributariesleft': 'nan', 'tributariesRight - eng': 'nan', 'tributariesright': 'nan', 'othernames - eng': 'nan', 'othernames': 'nan', 'source - eng': 'nan', 'source': 'nan', 'discharge2Location - eng': 'nan', 'discharge2Location': 'nan', 'thumbnail - eng': 'Lleida-Riu de Lleida.jpg?width=300', 'wikiPageWikiLink - eng': 'La Mitjana, Llivia, List of rivers of Catalonia, Catalonia, Arabs, French Cerdagne, Ancient Rome, Spain, Ancient Greece, Mequinenza, Gran Valira, Bourg-Madame, River source, Pic del Segre, Saillagouse, Els Camps Elisis, Puigcerda, List of rivers of Spain, Lleida, Al-Andalus, Balaguer, Cinca (Spain), Noguera Pallaresa, Pyrenees, Ebro, Pyrenees-Orientales, Cerdanya, La Seu dUrgell, Andorra, France, Noguera Ribagorchana, Catalan language', 'dbpedia_link': 'http://dbpedia.org/resource/Segre_(river)', 'wikipedia_link': 'https://en.wikipedia.org/wiki/Segre_(river)', 'river name - eng': '  Segre   ', 'Country - eng': 'nan', 'country': 'nan', 'State - eng': 'nan', 'states': 'nan', 'Region - eng': 'nan', 'region': 'nan', 'Basin size - eng': 'nan', 'basinsize': 'nan', 'Source-elevation - eng': '  2,400 m (7,900 ft)  ', 'sourceelevation': '2,400 మీటర్లు (7,900 అడుగులు)', 'Discharge-average - eng': 'nan', 'discharge_average': 'nan', 'Discharge-minimum - eng': 'nan', 'discharge_min': 'nan', 'Discharge-maximum - eng': 'nan', 'discharge_max': 'nan', 'Mouth-elevation - eng': 'nan', 'mouthelevation': 'nan', 'map': 'nan', 'image_url': 'Llobregat_2.jpg'}
#
#
#
#
#
# {{Infobox river
# | name = సెగ్రే
# | image =
# | image_size = 300
# |image_caption =సెగ్రే నది
# | length=265.0 కి.మీ.
# | source1_location = పైరినీస్
# | source1_elevation =2,400 మీటర్లు (7,900 అడుగులు) కి.మీ.
# | mouth_location = ఈబ్రో
# }}
#     సెగ్రే నది పొడవు 265.0 కిలోమీటర్లు. <ref name="wiki_link">{{Cite web|url=https://en.wikipedia.org/wiki/Segre_(river)|title=Segre |work=Wikipedia |language=en |access-date=2022-06-21}}</ref>
#
# ==భౌగోళిక ప్రదేశం(ప్రాంతం)==
#
# ఈ నది అక్షాంశం(లాటిట్యూడ్) 42.4022, రేఖాంశం(లాంగిట్యూడ్) 2.10861.<ref name="dbpedia_link">{{Cite web|url=http://dbpedia.org/resource/Segre_(river)|title=About: |last=|first=|date=|website=dbpedia.org|url-status=live|archive-url=|archive-date=|access-date=2022-06-24}}</ref>
#
# ==నది ప్రవాహం==
#
# పైరినీస్ దగ్గర సెగ్రే నది మొదలవుతుంది.<ref name="dbpedia_link" />ఈ నది మూలం ఎత్తు 2,400 మీటర్లు (7,900 అడుగులు).<ref name="wiki_link" />ఈ నది ఈబ్రో దగ్గర సముద్రంలో కలుస్తుంది.<ref name="dbpedia_link" />
# ==మూలాలు==
# <references />
#
# [[వర్గం:నదులు]][[వర్గం:https://en.wikipedia.org/wiki/Segre_(river)నదులు]]
#  [[వర్గం:http://dbpedia.org/resource/Segre_(river)నదులు]]
#
#
# [[వర్గం:తెవికీ నదులు]]
#
#  98 సెగ్రే
# {'river_name': 'Illinois ', 'rivername': 'ఇల్లినాయిస్', 'length': '439.351', 'mouthplace - eng': 'Illinois, Grafton, Illinois, United States', 'mouthplace': 'ఇల్లినాయిస్, గ్రాఫ్టన్, ఇల్లినాయిస్, యునైటెడ్ స్టేట్స్', 'rivermouth - eng': 'Mississippi River', 'mouth': 'మిస్సిస్సిప్పి నది', 'mouthlocation - eng': 'Illinois, Grafton, Illinois, United States', 'mouthlocation': 'ఇల్లినాయిస్, గ్రాఫ్టన్, ఇల్లినాయిస్, యునైటెడ్ స్టేట్స్', 'source1Location - eng': 'Illinois', 'source1location': 'ఇల్లినాయిస్', 'geometry - eng': 'POINT(-88.260276794434 41.393611907959)', 'latitude': '41.3936', 'longitude': '-88.2603', 'subdivision - eng': 'Illinois, United States', 'discharge1Location - eng': 'Valley City, about  from the mouth', 'discharge_location': 'వ్యాలీ సిటీ, నోటి నుండి', 'tributariesLeft - eng': 'Sangamon River, Kankakee River, Mazon River, Mackinaw River', 'tributariesleft': 'సంగమోన్ నది, కంకాకీ నది, మజోన్ నది, మాకినావ్ నది', 'tributariesRight - eng': 'Fox River (Illinois River tributary)', 'tributariesright': 'ఫాక్స్ నది (ఇల్లినాయిస్ నది ఉపనది)', 'othernames - eng': 'nan', 'othernames': 'nan', 'source - eng': 'Confluence of the Kankakee and Des Plaines Rivers', 'source': 'కంకాకీ ఆఫ్ డెస్ ప్లెయిన్స్ నదుల సంగమం', 'discharge2Location - eng': 'nan', 'discharge2Location': 'nan', 'thumbnail - eng': 'Illinois River near LaSalle Illinois.jpg?width=300', 'wikiPageWikiLink - eng': 'File:Illinois River, seen from Starved Rock.jpg, Sewage, Mazon River, Gulf of Mexico, Mussel, LaSalle, Illinois, Indiana, Bureau County, Illinois, European colonization of the Americas, File:Illinois River aerial.jpg, Hardin, Illinois, Great Lakes, Society of Jesus, Creve Coeur, Illinois, Water pollution, Sewage treatment, Michigan, Greene County, Illinois, Fulton County, Illinois, Tributary, Chicago River, United States Army Corps of Engineers, Rock Island, Illinois, Naplate, Illinois, John Hartford, Abraham Lincoln Memorial Bridge, United States Environmental Protection Agency, Chicago, Kingston Mines, Illinois, MSN, Chautauqua National Wildlife Refuge, Missouri River, Peoria, Illinois, Beardstown, Illinois, Glacial lake outburst flood, Kankakee River, Channahon State Park, File:Illinois 1718.jpg, Calhoun County, Illinois, Havana, Illinois, North Utica, Illinois, Rivers of America Series, Ice cutting, Mississippi River, Fort Crevecoeur, Pekin, Illinois, Overfishing, Tazewell County, Illinois, Spring Bay, Illinois, Springfield, Illinois, Wisconsin, Sangamon River, Naples, Illinois, Asian carp in North America, Henry, Illinois, Pearl, Illinois, List of crossings of the Illinois River, Sauger, Lake Michigan, Kampsville, Illinois, Valley City, Illinois, Gebhard Woods State Park, Des Plaines River, Bath, Illinois, Jersey County, Illinois, Mackinaw River, Last Glacial Period, Illinois and Michigan Canal, Siltation, List of rivers of Illinois, United States, Columbia River, Great Loop, Seneca, Illinois, Metropolitan Water Reclamation District of Greater Chicago, Peru, Illinois, Morris, Illinois, Combined sewer, Lacon, Illinois, Spoon River, Florence, Illinois, Hennepin Canal Parkway State Park, Grundy County, Illinois, Button, Illinois Environmental Protection Agency, Browning, Illinois, Marseilles, Illinois, Peoria Riverfront Museum, Vermilion River (Illinois River tributary), Grand Village of the Illinois, Shabbona Trail, Illinois Country, Fox River (Illinois River tributary), Grafton, Illinois, St. Louis, Chicago Sanitary and Ship Canal, Illinoian (stage), Spring Valley, Illinois, Rene-Robert Cavelier, Sieur de La Salle, East Peoria, Illinois, Illinois Waterway, La Moine River, Macoupin Creek, Beaver Wars, Ottawa, Illinois, Illinois, Oglesby, Illinois, Joliet, Illinois, U.S. state, Meredosia, Illinois, Chillicothe, Illinois, Hennepin, Illinois, Native Americans in the United States, Rome, Illinois, Clean Water Act, Jacques Marquette, Illinois Confederation, File:Starved Rock Lock (COE) tow downbound.jpg, Liverpool, Illinois, Starved Rock State Park, Kankakee Torrent, ...
#
#
#
#
#
# {{Infobox river
# | name = ఇల్లినాయిస్
# | image =
# | image_size = 300
# |image_caption =ఇల్లినాయిస్ నది
# | subdivision_type1  = దేశం
# | subdivision_name1  = యునైటెడ్ స్టేట్స్ ఆఫ్ అమెరికా
# | subdivision_type2  = రాష్ట్రం
# | subdivision_name2  = ఇల్లినాయిస్
# | length=439.351 కి.మీ.
# | discharge1_location= వ్యాలీ సిటీ, నోటి నుండి
# | discharge1_min= 1330 క్యూబిక్ అడుగులు (38 క్యూబిక్ మీటర్లు)
# | discharge1_avg = 23,280 ఘనపు అడుగులు/సెకండ్ (659 ఘనపు మీటర్/సెకండ్)
# | discharge1_max = 123,000 క్యూబిక్ అడుగులు (3,500 క్యూబిక్ మీటర్లు)
# | source1 = కంకాకీ ఆఫ్ డెస్ ప్లెయిన్స్ నదుల సంగమం
# | source1_location = ఇల్లినాయిస్
# | source1_elevation =505 అడుగులు (154 మీటర్లు) కి.మీ.
# | mouth= మిస్సిస్సిప్పి నది
# | mouth_location = ఇల్లినాయిస్, గ్రాఫ్టన్, ఇల్లినాయిస్, యునైటెడ్ స్టేట్స్
# | mouth_elevation =417 అడుగులు (127 మీటర్లు) కి.మీ.
# | basin_size = 28,070 చదరపు మైళ్ళు (72,700 చదరపు కిలోమీటర్లు)
# | tributaries_left = సంగమోన్ నది, కంకాకీ నది, మజోన్ నది, మాకినావ్ నది
# | tributaries_right = ఫాక్స్ నది (ఇల్లినాయిస్ నది ఉపనది)
# }}
#     ఇల్లినాయిస్ నది [[యునైటెడ్ స్టేట్స్ ఆఫ్ అమెరికా]] దేశమునకు చెందినది.ఇల్లినాయిస్ నది ఇల్లినాయిస్ రాష్ట్రాలలో ప్రవహిస్తుంది.ఈ నది పొడవు 439.351కిలోమీటర్లు.<ref name="wiki_link">{{Cite web|url=https://en.wikipedia.org/wiki/Illinois_River|title=Illinois |work=Wikipedia |language=en |access-date=2022-06-21}}</ref>
#
# ==భౌగోళిక ప్రదేశం(ప్రాంతం)==
#
# ఇల్లినాయిస్ నది పరీవాహక ప్రాంతం 28,070 చదరపు మైళ్ళు (72,700 చదరపు కిలోమీటర్లు) చదరపు కిలోమీటర్లు.<ref name="wiki_link" />ఈ నది అక్షాంశం(లాటిట్యూడ్) 41.3936, రేఖాంశం(లాంగిట్యూడ్) -88.2603.<ref name="dbpedia_link">{{Cite web|url=http://dbpedia.org/resource/Illinois_River|title=About: |last=|first=|date=|website=dbpedia.org|url-status=live|archive-url=|archive-date=|access-date=2022-06-24}}</ref>
#
# ==నది ఉపనదులు==
#
# ఇల్లినాయిస్ నది ఎడమ ఉపనదులు సంగమోన్ నది, కంకాకీ నది, మజోన్ నది, మాకినావ్ నది.ఇల్లినాయిస్ నది కుడి ఉపనదులు ఫాక్స్ నది (ఇల్లినాయిస్ నది ఉపనది).<ref name="dbpedia_link" />
#
# ==నది ప్రవాహం==
#
# [[యునైటెడ్ స్టేట్స్ ఆఫ్ అమెరికా]]లోని కంకాకీ ఆఫ్ డెస్ ప్లెయిన్స్ నదుల సంగమంలోని ఇల్లినాయిస్ దగ్గర ఇల్లినాయిస్ నది మొదలవుతుంది.<ref name="dbpedia_link" />ఈ నది మూలం ఎత్తు 505 అడుగులు (154 మీటర్లు).<ref name="wiki_link" />ఇల్లినాయిస్ నది ఇల్లినాయిస్, గ్రాఫ్టన్, ఇల్లినాయిస్, యునైటెడ్ స్టేట్స్ దగ్గర [[మిస్సిస్సిప్పి నది]]లో కలుస్తుంది.<ref name="dbpedia_link" />ఈ నది 417 అడుగులు (127 మీటర్లు) ఎత్తునుంచి సముద్రంలో కలుస్తుంది.<ref name="wiki_link" />
#
# ==సముద్రంలో నీటి విడుదల==
#
# ఇల్లినాయిస్ నది వ్యాలీ సిటీ, నోటి నుండి వద్ద సముద్రంలో కలుస్తుంది.<ref name="dbpedia_link" />ఇల్లినాయిస్ నది లోని నీరు క్షణముకు సగటు 23,280 ఘనపు అడుగులు/సెకండ్ (659 ఘనపు మీటర్/సెకండ్).<ref name="wiki_link" /> ఇప్పటి వరకు నమోదు అయినా రికార్డుల ప్రకారం ఇల్లినాయిస్ నది లోని నీరు క్షణముకు గరిష్ట మోతాదు 123,000 క్యూబిక్ అడుగులు (3,500 క్యూబిక్ మీటర్లు).<ref name="wiki_link" />ఇప్పటి వరకు నమోదు అయినా కనిష్ట మోతాదు క్షణముకు 1330 క్యూబిక్ అడుగులు (38 క్యూబిక్ మీటర్లు).<ref name="wiki_link" />
# ==మూలాలు==
# <references />
#
# [[వర్గం:నదులు]][[వర్గం:https://en.wikipedia.org/wiki/Illinois_Riverనదులు]]
#  [[వర్గం:http://dbpedia.org/resource/Illinois_Riverనదులు]]
#
#
# [[వర్గం:తెవికీ నదులు]]
#
#  99 ఇల్లినాయిస్
# {'river_name': 'Au Sable  (Michigan)', 'rivername': 'ఔ సెబుల్ (మిషిగన్)', 'length': '222.089', 'mouthplace - eng': 'Lake Huron', 'mouthplace': 'హురాన్ సరస్సు', 'rivermouth - eng': 'nan', 'mouth': 'nan', 'mouthlocation - eng': 'Lake Huron at Au Sable, Michigan', 'mouthlocation': 'ఏ సాబుల్, మిచిగాన్ వద్ద లేక్ హురాన్', 'source1Location - eng': 'Frederic Township, Michigan, Crawford County, Michigan', 'source1location': 'ఫ్రెడెరిక్ టౌన్\u200cషిప్, మిచిగాన్, క్రాఫోర్డ్ కౌంటీ, మిచిగాన్', 'geometry - eng': 'POINT(-84.758056640625 44.80583190918)', 'latitude': '44.8058', 'longitude': '-84.7581', 'subdivision - eng': 'United States', 'discharge1Location - eng': 'nan', 'discharge_location': 'nan', 'tributariesLeft - eng': 'nan', 'tributariesleft': 'nan', 'tributariesRight - eng': 'nan', 'tributariesright': 'nan', 'othernames - eng': 'nan', 'othernames': 'nan', 'source - eng': 'nan', 'source': 'nan', 'discharge2Location - eng': 'nan', 'discharge2Location': 'nan', 'thumbnail - eng': 'Ausablerivermap.png?width=300', 'wikiPageWikiLink - eng': 'File:Iargo Springs Oscoda MI.jpg, Blue Ribbon fishery, Bald eagle, Iosco County, Michigan, Curtis Township, Michigan, Brown trout, Foote Dam, Iargo Springs, Au Sable, Michigan, Lake Huron, Thymallus, French language, Ausable River (Lake Huron), Grayling, Michigan, Mio Dam, Crawford County, Michigan, National Scenic Byway, Frederic Township, Michigan, Richfield Township, Roscommon County, Michigan, Alcona County, Michigan, Comins Township, Michigan, Loud Dam, Alcona Dam, Huron National Forest, Bagley Township, Michigan, File:Michigan History Museum July 2018 01 (The River That Changed the World).jpg, Roscommon, Michigan, Northern Michigan, Cooke Dam, Pine River (Michigan), Michigan, Roscommon County, Michigan, Ridable miniature railway, Fairview, Michigan, Lumbermans Monument, Oscoda, Michigan, Huron–Manistee National Forests, File:Au Sable Highbanks (26954774884).jpg, Au Sable River Canoe Marathon, Five Channels Dam, Montmorency County, Michigan, Jack pine, Ogemaw County, Michigan, Oscoda County, Michigan, Hydropower, Canoe, Mio, Michigan, Consumers Energy, Lovells Township, Michigan, Canoe sprint, Kirtlands warbler, National Wild and Scenic Rivers System, File:Canoes AuSableRiverMI.jpg, Lower Peninsula of Michigan, Brook trout, Otsego County, Michigan, Rocky Mountains, File:AuSableRiverQueen Michigan.jpg, File:FiveChannelsDam.jpg, Lewiston, Michigan, South Branch Township, Crawford County, Michigan', 'dbpedia_link': 'http://dbpedia.org/resource/Au_Sable_River_(Michigan)', 'wikipedia_link': 'https://en.wikipedia.org/wiki/Au_Sable_River_(Michigan)', 'river name - eng': '  Au Sable  (Michigan)  ', 'Country - eng': '  United States  ', 'country': 'యునైటెడ్ స్టేట్స్ ఆఫ్ అమెరికా', 'State - eng': 'nan', 'states': 'nan', 'Region - eng': 'nan', 'region': 'nan', 'Basin size - eng': 'nan', 'basinsize': 'nan', 'Source-elevation - eng': 'nan', 'sourceelevation': 'nan', 'Discharge-average - eng': 'nan', 'discharge_average': 'nan', 'Discharge-minimum - eng': 'nan', 'discharge_min': 'nan', 'Discharge-maximum - eng': 'nan', 'discharge_max': 'nan', 'Mouth-elevation - eng': '  581 ft (177 m) 1   ', 'mouthelevation': '581 అడుగులు (177 మీటర్లు)', 'map': 'nan', 'image_url': 'Deventer_zonsondergang_k.JPG'}
#
#
#
#
#
# {{Infobox river
# | name = ఔ సెబుల్ (మిషిగన్)
# | image =
# | image_size = 300
# |image_caption =ఔ సెబుల్ (మిషిగన్) నది
# | subdivision_type1  = దేశం
# | subdivision_name1  = యునైటెడ్ స్టేట్స్ ఆఫ్ అమెరికా
# | length=222.089 కి.మీ.
# | source1_location = ఫ్రెడెరిక్ టౌన్‌షిప్, మిచిగాన్, క్రాఫోర్డ్ కౌంటీ, మిచిగాన్
# | mouth_location = ఏ సాబుల్, మిచిగాన్ వద్ద లేక్ హురాన్
# | mouth_elevation =581 అడుగులు (177 మీటర్లు) కి.మీ.
# }}
#     ఔ సెబుల్ (మిషిగన్) నది [[యునైటెడ్ స్టేట్స్ ఆఫ్ అమెరికా]] దేశమునకు చెందినది.ఈ నది పొడవు 222.089కిలోమీటర్లు.<ref name="wiki_link">{{Cite web|url=https://en.wikipedia.org/wiki/Au_Sable_River_(Michigan)|title=Au Sable  (Michigan)|work=Wikipedia |language=en |access-date=2022-06-21}}</ref>
#
# ==భౌగోళిక ప్రదేశం(ప్రాంతం)==
#
# ఈ నది అక్షాంశం(లాటిట్యూడ్) 44.8058, రేఖాంశం(లాంగిట్యూడ్) -84.7581.<ref name="dbpedia_link">{{Cite web|url=http://dbpedia.org/resource/Au_Sable_River_(Michigan)|title=About: |last=|first=|date=|website=dbpedia.org|url-status=live|archive-url=|archive-date=|access-date=2022-06-24}}</ref>
#
# ==నది ప్రవాహం==
#
# [[యునైటెడ్ స్టేట్స్ ఆఫ్ అమెరికా]]లోని ఫ్రెడెరిక్ టౌన్‌షిప్, మిచిగాన్, క్రాఫోర్డ్ కౌంటీ, మిచిగాన్ దగ్గర ఔ సెబుల్ (మిషిగన్) నది మొదలవుతుంది.<ref name="dbpedia_link" />ఈ నది ఏ సాబుల్, మిచిగాన్ వద్ద లేక్ హురాన్ దగ్గర సముద్రంలో కలుస్తుంది.<ref name="dbpedia_link" />ఈ నది 581 అడుగులు (177 మీటర్లు) ఎత్తునుంచి సముద్రంలో కలుస్తుంది.<ref name="wiki_link" />
# ==మూలాలు==
# <references />
#
# [[వర్గం:నదులు]][[వర్గం:https://en.wikipedia.org/wiki/Au_Sable_River_(Michigan)నదులు]]
#  [[వర్గం:http://dbpedia.org/resource/Au_Sable_River_(Michigan)నదులు]]
#
#
# [[వర్గం:తెవికీ నదులు]]
#
#  100 ఔ సెబుల్ (మిషిగన్)
# {'river_name': 'Hari (Afghanistan)', 'rivername': 'హరి (ఆఫ్ఘనిస్తాన్)', 'length': '1100.0', 'mouthplace - eng': 'Karakum Desert', 'mouthplace': 'కారకుమ్ ఎడారి', 'rivermouth - eng': 'nan', 'mouth': 'nan', 'mouthlocation - eng': 'Karakum Desert', 'mouthlocation': 'కారకుమ్ ఎడారి', 'source1Location - eng': 'Koh-i-Baba', 'source1location': 'కోహ్-ఇ-బాబా', 'geometry - eng': 'POINT(66.716667175293 34.650001525879)', 'latitude': '34.65', 'longitude': '66.7167', 'subdivision - eng': 'Afghanistan، Iran and Turkmenistan', 'discharge1Location - eng': 'nan', 'discharge_location': 'nan', 'tributariesLeft - eng': 'nan', 'tributariesleft': 'nan', 'tributariesRight - eng': 'nan', 'tributariesright': 'nan', 'othernames - eng': 'nan', 'othernames': 'nan', 'source - eng': 'nan', 'source': 'nan', 'discharge2Location - eng': 'nan', 'discharge2Location': 'nan', 'thumbnail - eng': 'Jam Qasr Zarafshan.jpg?width=300', 'wikiPageWikiLink - eng': 'River, Iran, Herat, Afghan-India Friendship Dam, Alexander the Great, Chishti Sharif District, Drought, Minaret of Jam, Tejen, Sarayu, Drowning of Afghan refugees in the Hari River, Afghanistan, Hindu Kush, Avesta, Buddhism, File:Herat Hari Rud bridge.jpg, Kushk River, Ahal Region, Iran–Turkmenistan Friendship Dam, Hydroelectricity, Rigvedic rivers, Koh-i-Baba, Latin, Dam, Karakum Desert, Minaret, Rigveda, تگاب اوشلان, Badhyz State Nature Reserve, Herat Province, Turkmenistan', 'dbpedia_link': 'http://dbpedia.org/resource/Hari_(Afghanistan)', 'wikipedia_link': 'https://en.wikipedia.org/wiki/Hari_(Afghanistan)', 'river name - eng': '  Hari (Afghanistan)  ', 'Country - eng': 'nan', 'country': 'nan', 'State - eng': 'nan', 'states': 'nan', 'Region - eng': 'nan', 'region': 'nan', 'Basin size - eng': '  39,300 km2  ', 'basinsize': 'nan', 'Source-elevation - eng': 'nan', 'sourceelevation': 'nan', 'Discharge-average - eng': 'nan', 'discharge_average': 'nan', 'Discharge-minimum - eng': 'nan', 'discharge_min': 'nan', 'Discharge-maximum - eng': 'nan', 'discharge_max': 'nan', 'Mouth-elevation - eng': 'nan', 'mouthelevation': 'nan', 'map': 'nan', 'image_url': 'Andorra_la_Vella,_Valira_river.jpg'}
#
#
#
#
#
# {{Infobox river
# | name = హరి (ఆఫ్ఘనిస్తాన్)
# | image =
# | image_size = 300
# |image_caption =హరి (ఆఫ్ఘనిస్తాన్) నది
# | length=1100.0 కి.మీ.
# | source1_location = కోహ్-ఇ-బాబా
# | mouth_location = కారకుమ్ ఎడారి
# }}
#     ఈ నది పొడవు 1100.0కిలోమీటర్లు.<ref name="wiki_link">{{Cite web|url=https://en.wikipedia.org/wiki/Hari_(Afghanistan)|title=Hari (Afghanistan)|work=Wikipedia |language=en |access-date=2022-06-21}}</ref>
#
# ==భౌగోళిక ప్రదేశం(ప్రాంతం)==
#
# హరి (ఆఫ్ఘనిస్తాన్) నది అక్షాంశం(లాటిట్యూడ్) 34.65. హరి (ఆఫ్ఘనిస్తాన్) నది రేఖాంశం(లాంగిట్యూడ్) 66.7167.<ref name="dbpedia_link">{{Cite web|url=http://dbpedia.org/resource/Hari_(Afghanistan)|title=About: |last=|first=|date=|website=dbpedia.org|url-status=live|archive-url=|archive-date=|access-date=2022-06-24}}</ref>
#
# ==నది ప్రవాహం==
#
# హరి (ఆఫ్ఘనిస్తాన్) నది కోహ్-ఇ-బాబా దగ్గర మొదలవుతుంది.<ref name="dbpedia_link" />ఈ నది కారకుమ్ ఎడారి దగ్గర సముద్రంలో కలుస్తుంది.<ref name="dbpedia_link" />
# ==మూలాలు==
# <references />
#
# [[వర్గం:నదులు]][[వర్గం:https://en.wikipedia.org/wiki/Hari_(Afghanistan)నదులు]]
#  [[వర్గం:http://dbpedia.org/resource/Hari_(Afghanistan)నదులు]]
#
#
# [[వర్గం:తెవికీ నదులు]]
#
#  101 హరి (ఆఫ్ఘనిస్తాన్)
# {'river_name': 'Scheldt', 'rivername': 'షెల్డ్ట్', 'length': '360.0', 'mouthplace - eng': 'North Sea', 'mouthplace': 'నార్త్ సీ ', 'rivermouth - eng': 'nan', 'mouth': 'nan', 'mouthlocation - eng': 'North Sea', 'mouthlocation': 'ఉత్తరపు సముద్రం', 'source1Location - eng': 'France', 'source1location': 'ఫ్రాన్స్', 'geometry - eng': 'POINT(3.5288889408112 51.43083190918)', 'latitude': '51.4308', 'longitude': '3.52889', 'subdivision - eng': ', Belgium, Netherlands, France', 'discharge1Location - eng': 'nan', 'discharge_location': 'nan', 'tributariesLeft - eng': 'nan', 'tributariesleft': 'nan', 'tributariesRight - eng': 'nan', 'tributariesright': 'nan', 'othernames - eng': 'nan', 'othernames': 'nan', 'source - eng': 'nan', 'source': 'nan', 'discharge2Location - eng': 'nan', 'discharge2Location': 'nan', 'thumbnail - eng': 'Schelde Antwerpen.jpg?width=300', 'wikiPageWikiLink - eng': 'Rumst, Fee, Tubize, Zilverbeek, Aisne, Deulemont, Wamp (river), Hogneau, Hain (river), Mons, Mandel (river), Schijn, Port of Antwerp, West Frisian language, Iwuy, Roman Empire, Treaty of Versailles, Selle (Scheldt tributary), Kettle War, Sensee, Haine, Grobbendonk, Linkebeek, Aa (Antwerp), Rupel, Grimbergen, Crinchon, North Brabant, Clarence (river), Meregem, Antwerp, House of Habsburg, Zeelandic Flanders, Antwerp Province, Stegers, Lot, Belgium, Nave (river), Deule, Western Scheldt, French Revolution, Ablain-Saint-Nazaire, Trouille (river), Lys (river), Sint-Pieters-Leeuw, Dunkirk, Ruisseau dAncre, Carency, Lessines, Neerpedebeek, Lawe, Roman Britain, Woluwe, Battle of the Scheldt, Vrouwvliet, Dyle (river), Molenbeek (Erpe-Mere Bovenschelde), S:Paget-Tyrell Memorandum, Zwalm (river), Kluisbergen, Low German, Nivelles, Francia, France, Herk (river), Molenbeek (Zenne), Avelgem, Jeumont, Canal, Walcheren, File:1593 Valckenborch Ansicht von Antwerpen mit zugefrorener Schelde anagoria.JPG, Samme, Herk-de-Stad, Dendermonde, Sensee Canal, Aalst, Belgium, IJse, Hainaut Province, Demer, Terneuzen, Grote Gete, Estuary, Steenwerck, Holy Roman Empire, Ghent, Kasterlee, Aire-sur-la-Lys, Marcoing, Erclin, Hirondelle (river), North Sea, Ronse, Sturgeon, Napoleon, Douve, Rhine, Amalberga of Temse, Mark (Dender), Departments of France, Ottignies-Louvain-la-Neuve, Scheldt–Rhine Canal, Thiant, Gaverbeek, Peniche (barge), Zwalm, Drogenbos, Mechelen, Thyle (river), Zuun (river), Rupelmonde, Melsterbeek, Vilvoorde, County of Flanders, File:River Scheldt in Antwerp at sunset.jpg, Voer (Dijle), Levee, Amsterdam, Gete, Kleine Gete, Braine-le-Comte, Marque (river), Rixensart, Denain, Brussels, Ugy, Cambrai, Maalbeek, Wielsbeke, Grande Honelle, Wichelen, Halen, Zoutleeuw, Laak river, De Gorge, Senette, Swedish language, Comines-Warneton, Senne (river), Sint-Agatha-Rode, Nethen, Franks, Petite Honelle, Wimp (river), Rhonelle, Hulst, Heulebeek, Port, West Flanders, Kuurne, Geleytsbeek, Eastern Dender, Velp (river), Grez-Doiceau, File:Escaut Location.jpg, English language, Vlissingen, Seine, Durme, Westerlo, Torrent dEsnes, File:Truman Byrnes greeting HMS Hambledon 1945.jpg, Rhosne, Lens, Pas-de-Calais, East Flanders, Zulle (river), Provinces of Belgium, Gouy, Aisne, Fall of Antwerp, File:Antwerp across the Scheldt, photochrom.png, Rotselaar, Lier, Belgium, Thines, Eastern Scheldt, Meuse, Tournai, Oudenaarde, Ath, Lille, Wasquehal, Belgian Revolution, Scarpe (river), Striene, Conde-sur-lEscaut, Quievrain, Middelburg, Zeeland, Seventeen Provinces, First Canadian Army, Zuid-Beveland, Grand Nocq, Breskens, Nord (French department), Western Dender, Bouchain, Mortagne-du-Nord, Waterway, Valenciennes, Eauette, Belgium, Duchy of Brabant, Sluis, Leuven, Dutch Republic, Zeeland, Hordain, Molenbeek (Brussel, Provinces of the Netherlands, Molse Nete, Canal de Saint-Quentin, Huldenberg, Nete (river), Laquette, Molenbeek-Ter Erpenbeek, World War II, Laeken, Dender, Honelle, Souchez, Netherlands, Temse, Kortrijk, Nehalennia, Schaerbeek, Geel, Old English, Albert Canal, Herenthout, ecaillon (river), ...
#
#
#
#
#
# {{Infobox river
# | name = షెల్డ్ట్
# | image =
# | image_size = 300
# |image_caption =షెల్డ్ట్ నది
# | length=360.0 కి.మీ.
# | discharge1_avg = 40 ఘనపు మీటర్/సెకండ్ (1,400 ఘనపు అడుగులు/సెకండ్)
# | source1_location = ఫ్రాన్స్
# | source1_elevation =97 మీటర్లు (318 అడుగులు) కి.మీ.
# | mouth_location = ఉత్తరపు సముద్రం
# | basin_size = 21,863 చదరపు కిలోమీటర్లు (8,441 చదరపు మైళ్ళు)
# }}
#     ఈ నది పొడవు 360.0కిలోమీటర్లు.<ref name="wiki_link">{{Cite web|url=https://en.wikipedia.org/wiki/Scheldt|title=Scheldt|work=Wikipedia |language=en |access-date=2022-06-21}}</ref>
#
# ==భౌగోళిక ప్రదేశం(ప్రాంతం)==
#
# షెల్డ్ట్ నది పరీవాహక ప్రాంతం 21,863 చదరపు కిలోమీటర్లు (8,441 చదరపు మైళ్ళు) చదరపు కిలోమీటర్లు.<ref name="wiki_link" />షెల్డ్ట్ నది అక్షాంశం(లాటిట్యూడ్) 51.4308. షెల్డ్ట్ నది రేఖాంశం(లాంగిట్యూడ్) 3.52889.<ref name="dbpedia_link">{{Cite web|url=http://dbpedia.org/resource/Scheldt|title=About: |last=|first=|date=|website=dbpedia.org|url-status=live|archive-url=|archive-date=|access-date=2022-06-24}}</ref>
#
# ==నది ప్రవాహం==
#
# ఫ్రాన్స్ దగ్గర షెల్డ్ట్ నది మొదలవుతుంది.<ref name="dbpedia_link" />ఈ నది మూలం ఎత్తు 97 మీటర్లు (318 అడుగులు).<ref name="wiki_link" />షెల్డ్ట్ నది ఉత్తరపు సముద్రం దగ్గర సముద్రంలో కలుస్తుంది.<ref name="dbpedia_link" />
#
# ==సముద్రంలో నీటి విడుదల==
#
# షెల్డ్ట్ నది లోని నీరు క్షణముకు సగటు 40 ఘనపు మీటర్/సెకండ్ (1,400 ఘనపు అడుగులు/సెకండ్).<ref name="wiki_link" />
# ==మూలాలు==
# <references />
#
# [[వర్గం:నదులు]][[వర్గం:https://en.wikipedia.org/wiki/Scheldtనదులు]]
#  [[వర్గం:http://dbpedia.org/resource/Scheldtనదులు]]
#
#
# [[వర్గం:తెవికీ నదులు]]
#
#  102 షెల్డ్ట్
# {'river_name': 'Ottawa ', 'rivername': 'ఒట్టావా', 'length': '1271.0', 'mouthplace - eng': 'Quebec, Ontario, Montreal, Canada, Ottawa', 'mouthplace': 'క్యూబెక్, అంటారియో, మాంట్రియల్, కెనడా, ఒట్టావా', 'rivermouth - eng': 'St. Lawrence River', 'mouth': 'సెయింట్ లారెన్స్ నది', 'mouthlocation - eng': 'Montreal, Quebec and Ottawa, Ontario, Canada', 'mouthlocation': 'మాంట్రియల్, క్యూబెక్ మరియు ఒట్టావా, అంటారియో, కెనడా', 'source1Location - eng': 'Lac-Moselle, Quebec, Quebec, Outaouais', 'source1location': 'లాక్-మోసెల్లే, క్యూబెక్, క్యూబెక్, ఔటౌయిస్', 'geometry - eng': 'POINT(-75.643058776855 47.643890380859)', 'latitude': '47.6439', 'longitude': '-75.6431', 'subdivision - eng': 'Ontario, Quebec, Canada', 'discharge1Location - eng': 'Carillon dam', 'discharge_location': 'కారిల్లాన్ ఆనకట్ట', 'tributariesLeft - eng': 'nan', 'tributariesleft': 'nan', 'tributariesRight - eng': 'nan', 'tributariesright': 'nan', 'othernames - eng': 'nan', 'othernames': 'nan', 'source - eng': 'Lac des Outaouais', 'source': 'లాక్ డెస్ ఔటౌయిస్', 'discharge2Location - eng': 'nan', 'discharge2Location': 'nan', 'thumbnail - eng': 'Ottawa-River.jpg?width=300', 'wikiPageWikiLink - eng': 'Rideau River, Lake Nipissing, Montreal River (Timiskaming District), South Nation River, War of 1812, Lorne Island, Great Lakes, Hen Island (Ottawa River), Farr Island, Dumoine River, eele DArcy, eele Allen, eele des Soeurs (Temiscamingue), Fort-Coulonge, Madawaska River (Ontario), eele Smith, eele Jones, Fur trade, eele Bryson, Clarence-Rockland, LOrignal, Burnt Island (Ottawa River), File:Ottawarivermattawa.jpg, eele Soulier, Braeside, King Edward Island, eele Oster, Davis Island (Ottawa River), Randolph Island, eele Yvette-Naubert, Dunlop Island (Ottawa River), Latour Island, eele Limerick, Parliament Hill, Victoria Island (Ottawa River), Haycock Island (Ontario), eele a Tom, eele Mohr, Coureur des bois, Shoal Island, Lower Duck Island, Kingston, Ontario, Lake Ontario, eele Dube, eele du Finlandais, eele Kettle, Landslide, Ottawa River timber trade, Head, Clara and Maria, Canadian canoe routes, Big Elbow Island, eele a Lawn, eele Gagnon, Demers Island (Ontario), Campbells Bay, Quebec, eele Pigs, eele Snake, Papineauville, Quebec, Dow Island, eele Reid (Clarendon), eele Paquin, Samuel de Champlain, Notre-Dame-du-Nord, eele Reid (LIsle-aux-Allumette, Sullivan Island (Ottawa River), Daisy Island, eele de Carillon, Fassett, Quebec, Cushing Island (Ontario), eele Verte (Temiscamingue), Bristol, Quebec, Clay, eeles a Cole, Oka, Quebec, Wabewawa Island, eele Hemlock, Chaudiere Falls, eele Wickens, Westmeath Provincial Park, eele Brunet, Vaudreuil-Dorion, eele Lafontaine, Lievre River, Irving Island (Ottawa River), Lac-Moselle, Quebec, Man Island (Ontario), Upper Duck Island, eele a Tom-Simon, Hamilton Island (Ottawa River), Mattawa River, Southern Ontario, eele Leblanc, Lake Champlain, Canadian Museum of History, eele Chenier, Riviere du Nord (Laurentide, eele Lafleur, Grenville, Quebec, eele Beique, eele Bernardin, File:Ottawa River Stromatolite Bed.jpg, eele Marcotte, Thurso, Quebec, eele Victoria, Rempnouix Island, List of rivers of Ontario, eele Mann, John Joe Island, Basil Island (Ottawa River), eele Frigon, eele Fitzpatrick, eele a Everill, Post-glacial rebound, Moffet, Quebec, St. Lawrence River, Ruby Islet, eele Winneway, Laurentian Valley, eele Dog, Hawkesbury, Ontario, Kate Island (Ontario), Princess Island (Ottawa River), Algonquin people, Saint-Placide, Quebec, Voyageurs, File:River Ottawa (view from the Peace Tower of Parliament Centre Block).JPG, Rouge River (Laurentide, Laverlochere-Angliers, Evelyn Island, Sandbar Island, Rocher a Gillis, eele des Quinze, Quyon, Public Services and Procurement Canada, Petrie Island, Sea level, Mesozoic, eele du Chenal Blind, Hazelton Island, Coulonge River, eele a Griffin, eele Fer a Cheval, Last Glacial Period, Outaouais, eele Brisseau, Bonnechere River, Fury Island, Logging camp, Lake Timiskaming, Ville-Marie, Quebec, eele Rita, List o ...
#
#
#
#
#
# {{Infobox river
# | name = ఒట్టావా
# | image =
# | image_size = 300
# |image_caption =ఒట్టావా నది
# | subdivision_type1  = దేశం
# | subdivision_name1  = కెనడా
# | length=1271.0 కి.మీ.
# | discharge1_location= కారిల్లాన్ ఆనకట్ట
# | discharge1_min= 749 క్యూబిక్ మీటర్లు (26500 క్యూబిక్ అడుగులు)
# | discharge1_avg = 1,950 ఘనపు మీటర్/సెకండ్ (69,000 ఘనపు అడుగులు/సెకండ్)
# | discharge1_max = 5,351 క్యూబిక్ మీటర్లు (189,000 క్యూబిక్ అడుగులు)
# | source1 = లాక్ డెస్ ఔటౌయిస్
# | source1_location = లాక్-మోసెల్లే, క్యూబెక్, క్యూబెక్, ఔటౌయిస్
# | mouth= సెయింట్ లారెన్స్ నది
# | mouth_location = మాంట్రియల్, క్యూబెక్ మరియు ఒట్టావా, అంటారియో, కెనడా
# | basin_size = 146,300 చదరపు కిలోమీటర్లు (56,500 చదరపు మైళ్ళు)
# }}
#     ఒట్టావా నది [[కెనడా]] దేశానికి చెందినది.ఒట్టావా నది 1271.0 కిలోమీటర్లు పొడవు ఉంటుంది.<ref name="wiki_link">{{Cite web|url=https://en.wikipedia.org/wiki/Ottawa_River|title=Ottawa |work=Wikipedia |language=en |access-date=2022-06-21}}</ref>
#
# ==భౌగోళిక ప్రదేశం(ప్రాంతం)==
#
# ఒట్టావా నది పరీవాహక ప్రాంతం 146,300 చదరపు కిలోమీటర్లు (56,500 చదరపు మైళ్ళు) చదరపు కిలోమీటర్లు.<ref name="wiki_link" />ఒట్టావా నది అక్షాంశం(లాటిట్యూడ్) 47.6439, రేఖాంశం(లాంగిట్యూడ్) -75.6431.<ref name="dbpedia_link">{{Cite web|url=http://dbpedia.org/resource/Ottawa_River|title=About: |last=|first=|date=|website=dbpedia.org|url-status=live|archive-url=|archive-date=|access-date=2022-06-24}}</ref>
#
# ==నది ప్రవాహం==
#
# [[కెనడా]]లోని లాక్ డెస్ ఔటౌయిస్లోని లాక్-మోసెల్లే, క్యూబెక్, క్యూబెక్, ఔటౌయిస్ దగ్గర ఒట్టావా నది మొదలవుతుంది.<ref name="dbpedia_link" />ఒట్టావా నది మాంట్రియల్, క్యూబెక్ మరియు ఒట్టావా, అంటారియో, కెనడా దగ్గర [[సెయింట్ లారెన్స్ నది]]లో కలుస్తుంది.<ref name="dbpedia_link" />
#
# ==సముద్రంలో నీటి విడుదల==
#
# ఒట్టావా నది కారిల్లాన్ ఆనకట్ట వద్ద సముద్రంలో కలుస్తుంది.<ref name="dbpedia_link" />ఈ నది లోని నీరు క్షణముకు సగటు 1,950 ఘనపు మీటర్/సెకండ్ (69,000 ఘనపు అడుగులు/సెకండ్). <ref name="wiki_link" />ఇప్పటి వరకు నమోదు అయినా గరిష్ట మోతాదు క్షణముకు 5,351 క్యూబిక్ మీటర్లు (189,000 క్యూబిక్ అడుగులు).<ref name="wiki_link" />ఇప్పటి వరకు నమోదు అయినా కనిష్ట మోతాదు క్షణముకు 749 క్యూబిక్ మీటర్లు (26500 క్యూబిక్ అడుగులు).<ref name="wiki_link" />
# ==మూలాలు==
# <references />
#
# [[వర్గం:నదులు]][[వర్గం:https://en.wikipedia.org/wiki/Ottawa_Riverనదులు]]
#  [[వర్గం:http://dbpedia.org/resource/Ottawa_Riverనదులు]]
#
#
# [[వర్గం:తెవికీ నదులు]]
#
#  103 ఒట్టావా
# {'river_name': 'Acheron', 'rivername': 'అచెరోన్', 'length': '52.0', 'mouthplace - eng': 'Ionian Sea', 'mouthplace': 'అయోనియన్ సముద్రం', 'rivermouth - eng': 'nan', 'mouth': 'nan', 'mouthlocation - eng': 'Ionian Sea', 'mouthlocation': 'అయోనియన్ సముద్రం', 'source1Location - eng': 'Ioannina (regional unit), Epirus', 'source1location': 'ఐయోనినా (ప్రాంతీయ యూనిట్), ఎపిరస్', 'geometry - eng': 'POINT(20.476110458374 39.236110687256)', 'latitude': '39.2361', 'longitude': '20.4761', 'subdivision - eng': 'Greece', 'discharge1Location - eng': 'nan', 'discharge_location': 'nan', 'tributariesLeft - eng': 'nan', 'tributariesleft': 'nan', 'tributariesRight - eng': 'nan', 'tributariesright': 'nan', 'othernames - eng': 'nan', 'othernames': 'nan', 'source - eng': 'nan', 'source': 'nan', 'discharge2Location - eng': 'nan', 'discharge2Location': 'nan', 'thumbnail - eng': 'Acheron river 2.jpg?width=300', 'wikiPageWikiLink - eng': 'Alien (franchise), Helios, Orphne, Ovid, File:The Vestibule of Hell and Souls Mustering to Cross the Acheron Blake.jpg, HMS Acheron, World of Warcraft, Ioannina (regional unit), Alcestis, Mephistopheles, Propertius, Greece, Callimachus, Aeneid, Plato, Saint Seiya, Aristophanes, Eurasian penduline tit, Avernus, Dante Alighieri, Suda, Tartarus, Hell, Robert E. Howard, Alien (creature in Alien franchise), Demeter, The Frogs, Apollonius of Rhodes, Hades, Conan the Barbarian, Virgil, Doctor Faustus (play), Zeus, Aliens (film), Statius, Euripides, Styx, AMC (TV channel), Argonauts, Conan the Barbarian (2011 film), Ascalaphus (son of Acheron), Destiny (video game), Truss, Selloi, Ioannina, Oceanus, Roman people, Greek mythology, Parga, Homer, Gaia, Ionian Sea, Percy Jackson & the Olympians, Faust, The Hour of the Dragon, Epirus (region), Alien (film), Turkey, Christopher Marlowe, The Interpretation of Dreams, Karadeniz Ereğli, Greek underworld, Corfu, The Walking Dead (TV serie, Pausanias (geographer), Dungeons & Dragons, Ammoudia, Preveza, Jack Aubrey, Master and Commander: The Far Side of the World, Phlegethon, Titans, River, Acheron Lake, Charon, The Hyborian Age, Necromanteion of Acheron, File:Gustave Dore, The Divine comedy, Inferno, plate 9, Charon, The Ferryman of Hell.jpg, Sigmund Freud, The Walking Dead (season 11), Cocytus, Divine Comedy, Arthas Menethil, Glyki, Acheron: Part I, Aeschylus, Synecdoche, Antarctica, Pindar, Epirus', 'dbpedia_link': 'http://dbpedia.org/resource/Acheron', 'wikipedia_link': 'https://en.wikipedia.org/wiki/Acheron', 'river name - eng': '  Acheron  ', 'Country - eng': '  Greece  ', 'country': 'గ్రీస్', 'State - eng': 'nan', 'states': 'nan', 'Region - eng': 'nan', 'region': 'nan', 'Basin size - eng': '  705 km2 (272 sq mi)  ', 'basinsize': '705 చదరపు కిలోమీటర్లు (272 చదరపు మైళ్ళు)', 'Source-elevation - eng': 'nan', 'sourceelevation': 'nan', 'Discharge-average - eng': 'nan', 'discharge_average': 'nan', 'Discharge-minimum - eng': 'nan', 'discharge_min': 'nan', 'Discharge-maximum - eng': 'nan', 'discharge_max': 'nan', 'Mouth-elevation - eng': 'nan', 'mouthelevation': 'nan', 'map': 'nan', 'image_url': 'Sevilla-3-13_(48040371651).jpg'}
#
#
#
#
#
# {{Infobox river
# | name = అచెరోన్
# | image =
# | image_size = 300
# |image_caption =అచెరోన్ నది
# | subdivision_type1  = దేశం
# | subdivision_name1  = గ్రీస్
# | length=52.0 కి.మీ.
# | source1_location = ఐయోనినా (ప్రాంతీయ యూనిట్), ఎపిరస్
# | mouth_location = అయోనియన్ సముద్రం
# | basin_size = 705 చదరపు కిలోమీటర్లు (272 చదరపు మైళ్ళు)
# }}
#     అచెరోన్ నది [[గ్రీస్]] దేశానికి చెందినది.అచెరోన్ నది 52.0 కిలోమీటర్లు పొడవు ఉంటుంది.<ref name="wiki_link">{{Cite web|url=https://en.wikipedia.org/wiki/Acheron|title=Acheron|work=Wikipedia |language=en |access-date=2022-06-21}}</ref>
#
# ==భౌగోళిక ప్రదేశం(ప్రాంతం)==
#
# అచెరోన్ నది 705 చదరపు కిలోమీటర్లు (272 చదరపు మైళ్ళు) చదరపు కిలోమీటర్ల పరీవాహక ప్రాంతం కలిగి ఉంటుంది.<ref name="wiki_link" />అచెరోన్ నది అక్షాంశం(లాటిట్యూడ్) 39.2361, రేఖాంశం(లాంగిట్యూడ్) 20.4761.<ref name="dbpedia_link">{{Cite web|url=http://dbpedia.org/resource/Acheron|title=About: |last=|first=|date=|website=dbpedia.org|url-status=live|archive-url=|archive-date=|access-date=2022-06-24}}</ref>
#
# ==నది ప్రవాహం==
#
# అచెరోన్ నది [[గ్రీస్]]లోని ఐయోనినా (ప్రాంతీయ యూనిట్), ఎపిరస్ దగ్గర మొదలవుతుంది.<ref name="dbpedia_link" />ఈ నది అయోనియన్ సముద్రం దగ్గర సముద్రంలో కలుస్తుంది.<ref name="dbpedia_link" />
# ==మూలాలు==
# <references />
#
# [[వర్గం:నదులు]][[వర్గం:https://en.wikipedia.org/wiki/Acheronనదులు]]
#  [[వర్గం:http://dbpedia.org/resource/Acheronనదులు]]
#
#
# [[వర్గం:తెవికీ నదులు]]
#
#  104 అచెరోన్
# {'river_name': 'Syr Darya', 'rivername': 'సిర్ దర్యా', 'length': '2256.25', 'mouthplace - eng': 'Kazakhstan, Kazaly', 'mouthplace': 'కజకిస్తాన్, కజలీ', 'rivermouth - eng': 'North Aral Sea', 'mouth': 'ఉత్తర అరల్ సముద్రం', 'mouthlocation - eng': 'Kazakhstan, Kazaly', 'mouthlocation': 'కజకిస్తాన్, కజలీ', 'source1Location - eng': 'Uzbekistan, Fergana Valley', 'source1location': 'ఉజ్బెకిస్తాన్, ఫెర్గానా వ్యాలీ', 'geometry - eng': 'POINT(71.757499694824 40.900833129883)', 'latitude': '40.9008', 'longitude': '71.7575', 'subdivision - eng': 'Kyrgyzstan, Kyzylorda, Khujand, Tashkent, Tajikistan, Baikonur, Turkistan (city), Kazakhstan, Uzbekistan', 'discharge1Location - eng': 'nan', 'discharge_location': 'nan', 'tributariesLeft - eng': 'Kara Darya', 'tributariesleft': 'కర దర్యా', 'tributariesRight - eng': 'Naryn (river), Sarysu (river)', 'tributariesright': 'నరిన్ (నది), సరిసు (నది)', 'othernames - eng': 'Jaxartes, Seyhun', 'othernames': 'జాక్సార్టెస్, సేహున్', 'source - eng': 'Confluence of Naryn and Kara Darya', 'source': 'నారిన్ , కారా దర్యాల సంగమం', 'discharge2Location - eng': 'nan', 'discharge2Location': 'nan', 'thumbnail - eng': 'Syr Darya.jpg?width=300', 'wikiPageWikiLink - eng': 'Muslim conquest of Transoxiana, History of the central steppe, Great Fergana Canal, Persian language, Jannah, Extreme points of Tajikistan, Kokand, Tajikistan, Baikonur, Khanate of Kokand, Alexander the Great, Middle Chinese, Turkistan (city), Alexandria Eschate, Talas (river), Tian Shan, Chu (river), Kyrgyzstan, Uzbekistan, North Aral Sea, Bactria, Cyrus the Great, Arys (river), Aral Sea, Tashkent, Sogdia, File:Khujand.jpg, Khiva, Early Muslim conquests, Kazakhstan, Cotton, River source, Russian conquest of Central Asia, Kyzylorda, Russian Empire, Abu al-Ghazi Bahadur, Acequia, Ancient Greek, Arabic, Tang dynasty, Cyropolis, File:Syr Darya River Floodplain, Kazakhstan, Central Asia.JPG, Endorheic basin, Etymology, Wikt:دریا, Kazaly, Fergana Valley, Rice, Kara Darya, Amu Darya, The Anabasis of Alexander, Environmental degradation, Fort Raim, Khujand, Dissolution of the Soviet Union, Paradise, Old Persian, Chirchiq (river), Naryn (river), Sarysu (river), Central Asia, Canal, Turkmenistan, Soviet Union', 'dbpedia_link': 'http://dbpedia.org/resource/Syr_Darya', 'wikipedia_link': 'https://en.wikipedia.org/wiki/Syr_Darya', 'river name - eng': '  Syr Darya  ', 'Country - eng': '  Kyrgyzstan, Uzbekistan, Tajikistan, Kazakhstan  ', 'country': 'కిర్గిజ్స్తాన్, ఉజ్బెకిస్తాన్, తజికిస్తాన్, కజకిస్తాన్', 'State - eng': 'nan', 'states': 'nan', 'Region - eng': 'nan', 'region': 'nan', 'Basin size - eng': '  402,760 km2 (155,510 sq mi)  ', 'basinsize': '402,760 చదరపు కిలోమీటర్లు (155,510 చదరపు మైళ్ళు)', 'Source-elevation - eng': '  400 m (1,300 ft)  ', 'sourceelevation': '400 మీటర్లు (1,300 అడుగులు)', 'Discharge-average - eng': '  1,180 m3/s (42,000 cu ft/s) 1   ', 'discharge_average': '1,180 ఘనపు మీటర్/సెకండ్ (42,000 ఘనపు అడుగులు/సెకండ్)', 'Discharge-minimum - eng': '  170 m3/s (6,000 cu ft/s)  ', 'discharge_min': '170 క్యూబిక్ మీటర్లు (6000 క్యూబిక్ అడుగులు)', 'Discharge-maximum - eng': '  3,900 m3/s (140,000 cu ft/s)  ', 'discharge_max': '3,900 క్యూబిక్ మీటర్లు (140,000 క్యూబిక్ అడుగులు)', 'Mouth-elevation - eng': '  42 m (138 ft)  ', 'mouthelevation': '42 మీటర్లు (138 అడుగులు)', 'map': 'nan', 'image_url': 'Mekong-River-Near-Luang-Prabang.jpg'}
#
#
#
#
#
# {{Infobox river
# | name = సిర్ దర్యా
# | image =
# | image_size = 300
# |image_caption =సిర్ దర్యా నది
# | subdivision_type1  = దేశం
# | subdivision_name1  = కిర్గిజ్స్తాన్, ఉజ్బెకిస్తాన్, తజికిస్తాన్, కజకిస్తాన్
# | length=2256.25 కి.మీ.
# | discharge1_min= 170 క్యూబిక్ మీటర్లు (6000 క్యూబిక్ అడుగులు)
# | discharge1_avg = 1,180 ఘనపు మీటర్/సెకండ్ (42,000 ఘనపు అడుగులు/సెకండ్)
# | discharge1_max = 3,900 క్యూబిక్ మీటర్లు (140,000 క్యూబిక్ అడుగులు)
# | source1 = నారిన్ , కారా దర్యాల సంగమం
# | source1_location = ఉజ్బెకిస్తాన్, ఫెర్గానా వ్యాలీ
# | source1_elevation =400 మీటర్లు (1,300 అడుగులు) కి.మీ.
# | mouth= ఉత్తర అరల్ సముద్రం
# | mouth_location = కజకిస్తాన్, కజలీ
# | mouth_elevation =42 మీటర్లు (138 అడుగులు) కి.మీ.
# | basin_size = 402,760 చదరపు కిలోమీటర్లు (155,510 చదరపు మైళ్ళు)
# | tributaries_left = కర దర్యా
# | tributaries_right = నరిన్ (నది), సరిసు (నది)
# }}
#     సిర్ దర్యా నది [[కిర్గిజ్స్తాన్, ఉజ్బెకిస్తాన్, తజికిస్తాన్, కజకిస్తాన్]] దేశమునకు చెందినది.సిర్ దర్యా నది ఇతర పేర్లు జాక్సార్టెస్, సేహున్.సిర్ దర్యా నది పొడవు 2256.25 కిలోమీటర్లు. <ref name="wiki_link">{{Cite web|url=https://en.wikipedia.org/wiki/Syr_Darya|title=Syr Darya|work=Wikipedia |language=en |access-date=2022-06-21}}</ref>
#
# ==భౌగోళిక ప్రదేశం(ప్రాంతం)==
#
# సిర్ దర్యా నది 402,760 చదరపు కిలోమీటర్లు (155,510 చదరపు మైళ్ళు) చదరపు కిలోమీటర్ల పరీవాహక ప్రాంతం కలిగి ఉంటుంది.<ref name="wiki_link" />ఈ నది అక్షాంశం(లాటిట్యూడ్) 40.9008. ఈ నది రేఖాంశం(లాంగిట్యూడ్) 71.7575.<ref name="dbpedia_link">{{Cite web|url=http://dbpedia.org/resource/Syr_Darya|title=About: |last=|first=|date=|website=dbpedia.org|url-status=live|archive-url=|archive-date=|access-date=2022-06-24}}</ref>
#
# ==నది ఉపనదులు==
#
# కర దర్యా,నరిన్ (నది), సరిసు (నది) మొదలగునవి సిర్ దర్యా నదికి ముఖ్యమైన ఉపనదులు.<ref name="dbpedia_link" />
#
# ==నది ప్రవాహం==
#
# [[కిర్గిజ్స్తాన్, ఉజ్బెకిస్తాన్, తజికిస్తాన్, కజకిస్తాన్]]లోని నారిన్ , కారా దర్యాల సంగమంలోని ఉజ్బెకిస్తాన్, ఫెర్గానా వ్యాలీ దగ్గర సిర్ దర్యా నది మొదలవుతుంది.<ref name="dbpedia_link" />ఈ నది మూలం ఎత్తు 400 మీటర్లు (1,300 అడుగులు).<ref name="wiki_link" />ఈ నది కజకిస్తాన్, కజలీ దగ్గర [[ఉత్తర అరల్ సముద్రం]]లో కలుస్తుంది.<ref name="dbpedia_link" />ఈ నది 42 మీటర్లు (138 అడుగులు) ఎత్తునుంచి సముద్రంలో కలుస్తుంది.<ref name="wiki_link" />
#
# ==సముద్రంలో నీటి విడుదల==
#
# ఈ నది లోని నీరు క్షణముకు సగటు 1,180 ఘనపు మీటర్/సెకండ్ (42,000 ఘనపు అడుగులు/సెకండ్). <ref name="wiki_link" /> ఇప్పటి వరకు నమోదు అయినా రికార్డుల ప్రకారం సిర్ దర్యా నది లోని నీరు క్షణముకు గరిష్ట మోతాదు 3,900 క్యూబిక్ మీటర్లు (140,000 క్యూబిక్ అడుగులు).<ref name="wiki_link" />ఇప్పటి వరకు నమోదు అయినా కనిష్ట మోతాదు క్షణముకు 170 క్యూబిక్ మీటర్లు (6000 క్యూబిక్ అడుగులు).<ref name="wiki_link" />
# ==మూలాలు==
# <references />
#
# [[వర్గం:నదులు]][[వర్గం:https://en.wikipedia.org/wiki/Syr_Daryaనదులు]]
#  [[వర్గం:http://dbpedia.org/resource/Syr_Daryaనదులు]]
#
#
# [[వర్గం:తెవికీ నదులు]]
#
#  105 సిర్ దర్యా
# {'river_name': 'Upper Angara', 'rivername': 'అప్పర్ అంగార', 'length': '438.0', 'mouthplace - eng': 'nan', 'mouthplace': 'nan', 'rivermouth - eng': 'Lake Baikal', 'mouth': 'బైకాల్ సరస్సు', 'mouthlocation - eng': 'nan', 'mouthlocation': 'nan', 'source1Location - eng': 'nan', 'source1location': 'nan', 'geometry - eng': 'POINT(113.75583648682 56.614166259766)', 'latitude': '56.6142', 'longitude': '113.756', 'subdivision - eng': 'Russia', 'discharge1Location - eng': 'nan', 'discharge_location': 'nan', 'tributariesLeft - eng': 'nan', 'tributariesleft': 'nan', 'tributariesRight - eng': 'nan', 'tributariesright': 'nan', 'othernames - eng': 'nan', 'othernames': 'nan', 'source - eng': 'Stanovoy Highlands, Delyun-Uran Range', 'source': '\nస్టానోవోయ్ హైలాండ్స్, డెల్యూన్-ఉరాన్ రేంజ్', 'discharge2Location - eng': 'nan', 'discharge2Location': 'nan', 'thumbnail - eng': 'Verkhnyaya Angara.jpg?width=300', 'wikiPageWikiLink - eng': 'Yanchukan, S:Encyclopædia Britannica, Ninth Edition, Delyun-Uran Range, Rapids, Upper and Lower Angara, Kotera (river), Angara, Upper Angara Range, Churo, Novy Uoyan, Russia, Floodplain, Lake Baikal, Barguzin Range, Volume II, Yarki Island, Glacial lake, File:Upper Angara Range ONC E-8.jpg, Baikal–Amur Mainline, Stanovoy Highlands, File:Enisey.png, Northern Muya Range, Yanchui, Buryatia, List of rivers of Russia, Siberia, Drainage basin', 'dbpedia_link': 'http://dbpedia.org/resource/Upper_Angara', 'wikipedia_link': 'https://en.wikipedia.org/wiki/Upper_Angara', 'river name - eng': '  Upper Angara  ', 'Country - eng': '  Russia  ', 'country': 'రష్యా', 'State - eng': 'nan', 'states': 'nan', 'Region - eng': 'nan', 'region': 'nan', 'Basin size - eng': '  21,400 km2 (8,300 sq mi)  ', 'basinsize': '21,400 చదరపు కిలోమీటర్లు (8,300 చదరపు మైళ్ళు)', 'Source-elevation - eng': '  1,600 m (5,200 ft)  ', 'sourceelevation': '1,600 మీటర్లు (5,200 అడుగులు)', 'Discharge-average - eng': '  258 m3/s (9,100 cu ft/s)  ', 'discharge_average': '258 ఘనపు మీటర్/సెకండ్ (9,100 ఘనపు అడుగులు/సెకండ్)', 'Discharge-minimum - eng': 'nan', 'discharge_min': 'nan', 'Discharge-maximum - eng': 'nan', 'discharge_max': 'nan', 'Mouth-elevation - eng': 'nan', 'mouthelevation': 'nan', 'map': 'nan', 'image_url': 'Lleida-Riu_de_Lleida.jpg'}
#
#
#
#
#
# {{Infobox river
# | name = అప్పర్ అంగార
# | image =
# | image_size = 300
# |image_caption =అప్పర్ అంగార నది
# | subdivision_type1  = దేశం
# | subdivision_name1  = రష్యా
# | length=438.0 కి.మీ.
# | discharge1_avg = 258 ఘనపు మీటర్/సెకండ్ (9,100 ఘనపు అడుగులు/సెకండ్)
# | source1 =
# స్టానోవోయ్ హైలాండ్స్, డెల్యూన్-ఉరాన్ రేంజ్
# | source1_elevation =1,600 మీటర్లు (5,200 అడుగులు) కి.మీ.
# | mouth= బైకాల్ సరస్సు
# | basin_size = 21,400 చదరపు కిలోమీటర్లు (8,300 చదరపు మైళ్ళు)
# }}
#     అప్పర్ అంగార నది [[రష్యా]] దేశమునకు చెందినది.ఈ నది పొడవు 438.0కిలోమీటర్లు.<ref name="wiki_link">{{Cite web|url=https://en.wikipedia.org/wiki/Upper_Angara|title=Upper Angara|work=Wikipedia |language=en |access-date=2022-06-21}}</ref>
#
# ==భౌగోళిక ప్రదేశం(ప్రాంతం)==
#
# అప్పర్ అంగార నది 21,400 చదరపు కిలోమీటర్లు (8,300 చదరపు మైళ్ళు) చదరపు కిలోమీటర్ల పరీవాహక ప్రాంతం కలిగి ఉంటుంది.<ref name="wiki_link" />అప్పర్ అంగార నది అక్షాంశం(లాటిట్యూడ్) 56.6142, రేఖాంశం(లాంగిట్యూడ్) 113.756.<ref name="dbpedia_link">{{Cite web|url=http://dbpedia.org/resource/Upper_Angara|title=About: |last=|first=|date=|website=dbpedia.org|url-status=live|archive-url=|archive-date=|access-date=2022-06-24}}</ref>
#
# ==నది ప్రవాహం==
#
# అప్పర్ అంగార నది [[రష్యా]]లోని
# స్టానోవోయ్ హైలాండ్స్, డెల్యూన్-ఉరాన్ రేంజ్లో  మొదలవుతుంది.<ref name="dbpedia_link" />అప్పర్ అంగార నది మూలం ఎత్తు 1,600 మీటర్లు (5,200 అడుగులు).<ref name="wiki_link" />ఈ నది [[బైకాల్ సరస్సు]]లో కలుస్తుంది. <ref name="dbpedia_link" />
#
# ==సముద్రంలో నీటి విడుదల==
#
# ఈ నది లోని నీరు క్షణముకు సగటు 258 ఘనపు మీటర్/సెకండ్ (9,100 ఘనపు అడుగులు/సెకండ్). <ref name="wiki_link" />
# ==మూలాలు==
# <references />
#
# [[వర్గం:నదులు]][[వర్గం:https://en.wikipedia.org/wiki/Upper_Angaraనదులు]]
#  [[వర్గం:http://dbpedia.org/resource/Upper_Angaraనదులు]]
#
#
# [[వర్గం:తెవికీ నదులు]]
#
#  106 అప్పర్ అంగార
# ...
# |image_caption =డెసెర్ట్ నది
# | source1 = లేక్ ఎడారి
# | source1_location = లాక్-పైథోంగా
# | mouth= గాటినో నది
# | mouth_location = మణివాకి
# | tributaries_right = ఐగల్ నది (ఎడారి నది ఉపనది)
# }}
#
# ==నది ఉపనదులు==
#
# డెసెర్ట్ నదికి గల కుడి ఉపనదులు ఐగల్ నది (ఎడారి నది ఉపనది).<ref name="dbpedia_link" />
#
# ==నది ప్రవాహం==
#
# డెసెర్ట్ నది లేక్ ఎడారిలోని లాక్-పైథోంగా దగ్గర మొదలవుతుంది.<ref name="dbpedia_link" />డెసెర్ట్ నది మణివాకి దగ్గర [[గాటినో నది]]లో కలుస్తుంది.<ref name="dbpedia_link" />
#
# ==సముద్రంలో నీటి విడుదల==
#
#
# ==మూలాలు==
# <references />
#
# [[వర్గం:నదులు]][[వర్గం:https://en.wikipedia.org/wiki/Desert_Riverనదులు]]
#  [[వర్గం:http://dbpedia.org/resource/Desert_Riverనదులు]]
#
#
# [[వర్గం:తెవికీ నదులు]]
#
#  27127 డెసెర్ట్
# {'river_name': 'Jeti-oguz ', 'rivername': 'జెట్టి-ఒగ్గుజు', 'length': '52.0', 'mouthplace - eng': 'nan', 'mouthplace': 'nan', 'rivermouth - eng': 'Issyk-Kul', 'mouth': 'ఇస్సిక్-కుల్', 'mouthlocation - eng': 'nan', 'mouthlocation': 'nan', 'source1Location - eng': 'Jeti-oguz District', 'source1location': 'జెటి-ఓగుజ్ జిల్లా', 'geometry - eng': 'POINT(78.071899414062 42.518199920654)', 'latitude': '42.5182', 'longitude': '78.0719', 'subdivision - eng': 'Kyrgyzstan', 'discharge1Location - eng': 'nan', 'discharge_location': 'nan', 'tributariesLeft - eng': 'nan', 'tributariesleft': 'nan', 'tributariesRight - eng': 'nan', 'tributariesright': 'nan', 'othernames - eng': 'nan', 'othernames': 'nan', 'source - eng': 'Terskey Ala-too', 'source': 'టెర్స్కీ అలా-టూ', 'discharge2Location - eng': 'nan', 'discharge2Location': 'nan', 'thumbnail - eng': 'River at Jety-Oguz (2564382042).jpg?width=300', 'wikiPageWikiLink - eng': 'Jeti-oguz District, Kyrgyzstan, Terskey Ala-too, Issyk-Kul Region, Jeti-oguz village, Jeti-oguz resort, Issyk-Kul', 'dbpedia_link': 'http://dbpedia.org/resource/Jeti-oguz_(river)', 'wikipedia_link': 'https://en.wikipedia.org/wiki/Jeti-oguz_(river)', 'river name - eng': 'nan', 'Country - eng': 'nan', 'country': 'nan', 'State - eng': 'nan', 'states': 'nan', 'Region - eng': 'nan', 'region': 'nan', 'Basin size - eng': 'nan', 'basinsize': 'nan', 'Source-elevation - eng': 'nan', 'sourceelevation': 'nan', 'Discharge-average - eng': 'nan', 'discharge_average': 'nan', 'Discharge-minimum - eng': 'nan', 'discharge_min': 'nan', 'Discharge-maximum - eng': 'nan', 'discharge_max': 'nan', 'Mouth-elevation - eng': 'nan', 'mouthelevation': 'nan', 'map': 'nan', 'image_url': 'nan'}
#
#
#
#
#
# {{Infobox river
# | name = జెట్టి-ఒగ్గుజు
# | image =
# | image_size = 300
# |image_caption =జెట్టి-ఒగ్గుజు నది
# | length=52.0 కి.మీ.
# | source1 = టెర్స్కీ అలా-టూ
# | source1_location = జెటి-ఓగుజ్ జిల్లా
# | mouth= ఇస్సిక్-కుల్
# }}
#     జెట్టి-ఒగ్గుజు నది పొడవు 52.0 కిలోమీటర్లు. <ref name="wiki_link">{{Cite web|url=https://en.wikipedia.org/wiki/Jeti-oguz_(river)|title=Jeti-oguz |work=Wikipedia |language=en |access-date=2022-06-21}}</ref>
#
# ==భౌగోళిక ప్రదేశం(ప్రాంతం)==
#
# జెట్టి-ఒగ్గుజు నది అక్షాంశం(లాటిట్యూడ్) 42.5182, రేఖాంశం(లాంగిట్యూడ్) 78.0719.<ref name="dbpedia_link">{{Cite web|url=http://dbpedia.org/resource/Jeti-oguz_(river)|title=About: |last=|first=|date=|website=dbpedia.org|url-status=live|archive-url=|archive-date=|access-date=2022-06-24}}</ref>
#
# ==నది ప్రవాహం==
#
# జెట్టి-ఒగ్గుజు నది టెర్స్కీ అలా-టూలోని జెటి-ఓగుజ్ జిల్లా దగ్గర మొదలవుతుంది.<ref name="dbpedia_link" />జెట్టి-ఒగ్గుజు నది [[ఇస్సిక్-కుల్]]లో కలుస్తుంది. <ref name="dbpedia_link" />
#
# ==సముద్రంలో నీటి విడుదల==
#
#
# ==మూలాలు==
# <references />
#
# [[వర్గం:నదులు]][[వర్గం:https://en.wikipedia.org/wiki/Jeti-oguz_(river)నదులు]]
#  [[వర్గం:http://dbpedia.org/resource/Jeti-oguz_(river)నదులు]]
#
#
# [[వర్గం:తెవికీ నదులు]]
#
#  27128 జెట్టి-ఒగ్గుజు
# {'river_name': 'Maygnaway ', 'rivername': 'మేగ్నావే', 'length': 'nan', 'mouthplace - eng': 'nan', 'mouthplace': 'nan', 'rivermouth - eng': 'nan', 'mouth': 'nan', 'mouthlocation - eng': 'nan', 'mouthlocation': 'nan', 'source1Location - eng': 'nan', 'source1location': 'nan', 'geometry - eng': 'POINT(124.05860900879 13.687222480774)', 'latitude': '13.6872', 'longitude': '124.059', 'subdivision - eng': 'Catanduanes, Philippines, Bicol Region', 'discharge1Location - eng': 'nan', 'discharge_location': 'nan', 'tributariesLeft - eng': 'nan', 'tributariesleft': 'nan', 'tributariesRight - eng': 'nan', 'tributariesright': 'nan', 'othernames - eng': 'nan', 'othernames': 'nan', 'source - eng': 'nan', 'source': 'nan', 'discharge2Location - eng': 'nan', 'discharge2Location': 'nan', 'thumbnail - eng': 'nan', 'wikiPageWikiLink - eng': 'Catanduanes, Philippine Sea, Philippines, Bicol Region', 'dbpedia_link': 'http://dbpedia.org/resource/Maygnaway_River', 'wikipedia_link': 'https://en.wikipedia.org/wiki/Maygnaway_River', 'river name - eng': 'nan', 'Country - eng': 'nan', 'country': 'nan', 'State - eng': 'nan', 'states': 'nan', 'Region - eng': 'nan', 'region': 'nan', 'Basin size - eng': 'nan', 'basinsize': 'nan', 'Source-elevation - eng': 'nan', 'sourceelevation': 'nan', 'Discharge-average - eng': 'nan', 'discharge_average': 'nan', 'Discharge-minimum - eng': 'nan', 'discharge_min': 'nan', 'Discharge-maximum - eng': 'nan', 'discharge_max': 'nan', 'Mouth-elevation - eng': 'nan', 'mouthelevation': 'nan', 'map': 'nan', 'image_url': 'nan'}
#
#
#
#
#
# {{Infobox river
# | name = మేగ్నావే
# | image =
# | image_size = 300
# |image_caption =మేగ్నావే నది
# }}
#
# ==భౌగోళిక ప్రదేశం(ప్రాంతం)==
#
# మేగ్నావే నది అక్షాంశం(లాటిట్యూడ్) 13.6872. మేగ్నావే నది రేఖాంశం(లాంగిట్యూడ్) 124.059.<ref name="dbpedia_link">{{Cite web|url=http://dbpedia.org/resource/Maygnaway_River|title=About: |last=|first=|date=|website=dbpedia.org|url-status=live|archive-url=|archive-date=|access-date=2022-06-24}}</ref>
# ==మూలాలు==
# <references />
#
# [[వర్గం:నదులు]][[వర్గం:https://en.wikipedia.org/wiki/Maygnaway_Riverనదులు]]
#  [[వర్గం:http://dbpedia.org/resource/Maygnaway_Riverనదులు]]
#
#
# [[వర్గం:తెవికీ నదులు]]
#
#  27129 మేగ్నావే
# {'river_name': 'Tampaon ', 'rivername': 'ట్యాంపాన్', 'length': 'nan', 'mouthplace - eng': 'nan', 'mouthplace': 'nan', 'rivermouth - eng': 'Moctezuma River', 'mouth': 'మోంటెజుమా నది', 'mouthlocation - eng': 'nan', 'mouthlocation': 'nan', 'source1Location - eng': 'nan', 'source1location': 'nan', 'geometry - eng': 'POINT(-98.562103271484 21.968200683594)', 'latitude': '21.9682', 'longitude': '-98.5621', 'subdivision - eng': 'San Luis Potosi, Mexico, Veracruz', 'discharge1Location - eng': 'nan', 'discharge_location': 'nan', 'tributariesLeft - eng': 'nan', 'tributariesleft': 'nan', 'tributariesRight - eng': 'nan', 'tributariesright': 'nan', 'othernames - eng': 'Tamuin River', 'othernames': 'టముయిన్ నది', 'source - eng': 'confluence of Santa Maria River and Rio Verde', 'source': 'శాంటా మారియా నది ఆఫ్ రియో వెర్డే సంగమం', 'discharge2Location - eng': 'nan', 'discharge2Location': 'nan', 'thumbnail - eng': 'Rio Tampaon (3683143148).jpg?width=300', 'wikiPageWikiLink - eng': 'Queretaro, Sierra Madre Oriental, Panuco River, Gulf Coastal Plain, Moctezuma River, Mexican Plateau, Santa Maria River (San Luis Potosi), Rio Verde (San Luis Potosi), List of states of Mexico, San Luis Potosi, Veracruz, Guanajuato', 'dbpedia_link': 'http://dbpedia.org/resource/Tampaon_River', 'wikipedia_link': 'https://en.wikipedia.org/wiki/Tampaon_River', 'river name - eng': 'nan', 'Country - eng': 'nan', 'country': 'nan', 'State - eng': 'nan', 'states': 'nan', 'Region - eng': 'nan', 'region': 'nan', 'Basin size - eng': 'nan', 'basinsize': 'nan', 'Source-elevation - eng': 'nan', 'sourceelevation': 'nan', 'Discharge-average - eng': 'nan', 'discharge_average': 'nan', 'Discharge-minimum - eng': 'nan', 'discharge_min': 'nan', 'Discharge-maximum - eng': 'nan', 'discharge_max': 'nan', 'Mouth-elevation - eng': 'nan', 'mouthelevation': 'nan', 'map': 'nan', 'image_url': 'nan'}
#
#
#
#
#
# {{Infobox river
# | name = ట్యాంపాన్
# | image =
# | image_size = 300
# |image_caption =ట్యాంపాన్ నది
# | source1 = శాంటా మారియా నది ఆఫ్ రియో వెర్డే సంగమం
# | mouth= మోంటెజుమా నది
# }}
#     ట్యాంపాన్ నదిని టముయిన్ నది అని కూడా పిలుస్తారు.
#
# ==భౌగోళిక ప్రదేశం(ప్రాంతం)==
#
# ట్యాంపాన్ నది అక్షాంశం(లాటిట్యూడ్) 21.9682. ట్యాంపాన్ నది రేఖాంశం(లాంగిట్యూడ్) -98.5621.<ref name="dbpedia_link">{{Cite web|url=http://dbpedia.org/resource/Tampaon_River|title=About: |last=|first=|date=|website=dbpedia.org|url-status=live|archive-url=|archive-date=|access-date=2022-06-24}}</ref>
#
# ==నది ప్రవాహం==
#
# ఈ నది [[మోంటెజుమా నది]]లో కలుస్తుంది. <ref name="dbpedia_link" />
#
# ==సముద్రంలో నీటి విడుదల==
#
#
# ==మూలాలు==
# <references />
#
# [[వర్గం:నదులు]][[వర్గం:https://en.wikipedia.org/wiki/Tampaon_Riverనదులు]]
#  [[వర్గం:http://dbpedia.org/resource/Tampaon_Riverనదులు]]
#
#
# [[వర్గం:తెవికీ నదులు]]
#
#  27130 ట్యాంపాన్
# {'river_name': 'Rio Coco', 'rivername': 'రియో కోకో', 'length': 'nan', 'mouthplace - eng': 'nan', 'mouthplace': 'nan', 'rivermouth - eng': 'nan', 'mouth': 'nan', 'mouthlocation - eng': 'nan', 'mouthlocation': 'nan', 'source1Location - eng': 'nan', 'source1location': 'nan', 'geometry - eng': 'nan', 'latitude': 'nan', 'longitude': 'nan', 'subdivision - eng': 'nan', 'discharge1Location - eng': 'nan', 'discharge_location': 'nan', 'tributariesLeft - eng': 'nan', 'tributariesleft': 'nan', 'tributariesRight - eng': 'nan', 'tributariesright': 'nan', 'othernames - eng': 'nan', 'othernames': 'nan', 'source - eng': 'nan', 'source': 'nan', 'discharge2Location - eng': 'nan', 'discharge2Location': 'nan', 'thumbnail - eng': 'Foz do Rio Coco - Sabiaguaba.jpg?width=300', 'wikiPageWikiLink - eng': 'Pacatuba, Ceara, Blue carbon, File:Coco 07.JPG, Ceara, Fortaleza, Mangrove restoration, File:Foz do Rio Coco - Sabiaguaba.jpg, Maracanau, Itaitinga', 'dbpedia_link': 'http://dbpedia.org/resource/Rio_Coco', 'wikipedia_link': 'https://en.wikipedia.org/wiki/Rio_Coco', 'river name - eng': 'nan', 'Country - eng': 'nan', 'country': 'nan', 'State - eng': 'nan', 'states': 'nan', 'Region - eng': 'nan', 'region': 'nan', 'Basin size - eng': 'nan', 'basinsize': 'nan', 'Source-elevation - eng': 'nan', 'sourceelevation': 'nan', 'Discharge-average - eng': 'nan', 'discharge_average': 'nan', 'Discharge-minimum - eng': 'nan', 'discharge_min': 'nan', 'Discharge-maximum - eng': 'nan', 'discharge_max': 'nan', 'Mouth-elevation - eng': 'nan', 'mouthelevation': 'nan', 'map': 'nan', 'image_url': 'nan'}
#
#
#
#
#
# {{Infobox river
# | name = రియో కోకో
# | image =
# | image_size = 300
# |image_caption =రియో కోకో నది
# }}
# ==మూలాలు==
# <references />
#
# [[వర్గం:నదులు]][[వర్గం:https://en.wikipedia.org/wiki/Rio_Cocoనదులు]]
#  [[వర్గం:http://dbpedia.org/resource/Rio_Cocoనదులు]]
#
#
# [[వర్గం:తెవికీ నదులు]]
#
#  27131 రియో కోకో
# {'river_name': 'Gardon dAles', 'rivername': "గార్డన్ డి'అలెస్", 'length': '61.0', 'mouthplace - eng': 'Ners', 'mouthplace': 'నెర్స్', 'rivermouth - eng': 'Gardon', 'mouth': 'రోచ్', 'mouthlocation - eng': 'Ners', 'mouthlocation': 'నెర్స్', 'source1Location - eng': 'Cevennes', 'source1location': 'సెవెన్స్', 'geometry - eng': 'POINT(4.1325001716614 44.03279876709)', 'latitude': '44.0328', 'longitude': '4.1325', 'subdivision - eng': 'France', 'discharge1Location - eng': 'nan', 'discharge_location': 'nan', 'tributariesLeft - eng': 'nan', 'tributariesleft': 'nan', 'tributariesRight - eng': 'nan', 'tributariesright': 'nan', 'othernames - eng': 'nan', 'othernames': 'nan', 'source - eng': 'nan', 'source': 'nan', 'discharge2Location - eng': 'nan', 'discharge2Location': 'nan', 'thumbnail - eng': 'Gardon in Ales 02.jpg?width=300', 'wikiPageWikiLink - eng': 'France, Gard, Gardon, Saint-Privat-de-Vallongue, Lozere, Cevennes, Ners, Ales', 'dbpedia_link': "http://dbpedia.org/resource/Gardon_d'Ales", 'wikipedia_link': "https://en.wikipedia.org/wiki/Gardon_d'Ales", 'river name - eng': 'nan', 'Country - eng': 'nan', 'country': 'nan', 'State - eng': 'nan', 'states': 'nan', 'Region - eng': 'nan', 'region': 'nan', 'Basin size - eng': 'nan', 'basinsize': 'nan', 'Source-elevation - eng': 'nan', 'sourceelevation': 'nan', 'Discharge-average - eng': 'nan', 'discharge_average': 'nan', 'Discharge-minimum - eng': 'nan', 'discharge_min': 'nan', 'Discharge-maximum - eng': 'nan', 'discharge_max': 'nan', 'Mouth-elevation - eng': 'nan', 'mouthelevation': 'nan', 'map': 'nan', 'image_url': 'Watson_Creek_and_Trail_California.jpg'}
#
#
#
#
#
# {{Infobox river
# | name = గార్డన్ డి'అలెస్
# | image =
# | image_size = 300
# |image_caption =గార్డన్ డి'అలెస్ నది
# | length=61.0 కి.మీ.
# | source1_location = సెవెన్స్
# | mouth= రోచ్
# | mouth_location = నెర్స్
# }}
#     గార్డన్ డి'అలెస్ నది పొడవు 61.0 కిలోమీటర్లు. <ref name="wiki_link">{{Cite web|url=https://en.wikipedia.org/wiki/Gardon_d'Ales|title=Gardon dAles|work=Wikipedia |language=en |access-date=2022-06-21}}</ref>
#
# ==భౌగోళిక ప్రదేశం(ప్రాంతం)==
#
# గార్డన్ డి'అలెస్ నది అక్షాంశం(లాటిట్యూడ్) 44.0328, రేఖాంశం(లాంగిట్యూడ్) 4.1325.<ref name="dbpedia_link">{{Cite web|url=http://dbpedia.org/resource/Gardon_d'Ales|title=About: |last=|first=|date=|website=dbpedia.org|url-status=live|archive-url=|archive-date=|access-date=2022-06-24}}</ref>
#
# ==నది ప్రవాహం==
#
# గార్డన్ డి'అలెస్ నది సెవెన్స్ దగ్గర మొదలవుతుంది.<ref name="dbpedia_link" />ఈ నది నెర్స్ దగ్గర [[రోచ్]]లో కలుస్తుంది.<ref name="dbpedia_link" />
#
# ==సముద్రంలో నీటి విడుదల==
#
#
# ==మూలాలు==
# <references />
#
# [[వర్గం:నదులు]][[వర్గం:https://en.wikipedia.org/wiki/Gardon_d'Alesనదులు]]
#  [[వర్గం:http://dbpedia.org/resource/Gardon_d'Alesనదులు]]
#
#
# [[వర్గం:తెవికీ నదులు]]
#
#  27132 గార్డన్ డి'అలెస్
# {'river_name': 'Nievre (Somme)', 'rivername': 'నియెవ్రే (సోమ్మే)', 'length': '22.0', 'mouthplace - eng': 'nan', 'mouthplace': 'nan', 'rivermouth - eng': 'Somme (river)', 'mouth': 'సొమ్మే (నది)', 'mouthlocation - eng': 'nan', 'mouthlocation': 'nan', 'source1Location - eng': 'nan', 'source1location': 'సొమ్మే (నది)', 'geometry - eng': 'POINT(2.0483999252319 50.009101867676)', 'latitude': '50.0091', 'longitude': '2.0484', 'subdivision - eng': 'France', 'discharge1Location - eng': 'nan', 'discharge_location': 'nan', 'tributariesLeft - eng': 'nan', 'tributariesleft': 'nan', 'tributariesRight - eng': 'nan', 'tributariesright': 'nan', 'othernames - eng': 'nan', 'othernames': 'nan', 'source - eng': 'nan', 'source': 'nan', 'discharge2Location - eng': 'nan', 'discharge2Location': 'nan', 'thumbnail - eng': 'Nievre a Flixecourt 1.jpg?width=300', 'wikiPageWikiLink - eng': 'France, Regions of France, Somme (river), Departments of France, List of rivers of France, Naours, Hauts-de-France, Communes of France, Somme (department), Flixecourt', 'dbpedia_link': 'http://dbpedia.org/resource/Nievre_(Somme)', 'wikipedia_link': 'https://en.wikipedia.org/wiki/Nievre_(Somme)', 'river name - eng': 'nan', 'Country - eng': 'nan', 'country': 'nan', 'State - eng': 'nan', 'states': 'nan', 'Region - eng': 'nan', 'region': 'nan', 'Basin size - eng': 'nan', 'basinsize': 'nan', 'Source-elevation - eng': 'nan', 'sourceelevation': 'nan', 'Discharge-average - eng': 'nan', 'discharge_average': 'nan', 'Discharge-minimum - eng': 'nan', 'discharge_min': 'nan', 'Discharge-maximum - eng': 'nan', 'discharge_max': 'nan', 'Mouth-elevation - eng': 'nan', 'mouthelevation': 'nan', 'map': 'nan', 'image_url': 'nan'}
#
#
#
#
#
# {{Infobox river
# | name = నియెవ్రే (సోమ్మే)
# | image =
# | image_size = 300
# |image_caption =నియెవ్రే (సోమ్మే) నది
# | length=22.0 కి.మీ.
# | source1_location = సొమ్మే (నది)
# | mouth= సొమ్మే (నది)
# }}
#     ఈ నది పొడవు 22.0కిలోమీటర్లు.<ref name="wiki_link">{{Cite web|url=https://en.wikipedia.org/wiki/Nievre_(Somme)|title=Nievre (Somme)|work=Wikipedia |language=en |access-date=2022-06-21}}</ref>
#
# ==భౌగోళిక ప్రదేశం(ప్రాంతం)==
#
# ఈ నది అక్షాంశం(లాటిట్యూడ్) 50.0091. ఈ నది రేఖాంశం(లాంగిట్యూడ్) 2.0484.<ref name="dbpedia_link">{{Cite web|url=http://dbpedia.org/resource/Nievre_(Somme)|title=About: |last=|first=|date=|website=dbpedia.org|url-status=live|archive-url=|archive-date=|access-date=2022-06-24}}</ref>
#
# ==నది ప్రవాహం==
#
# నియెవ్రే (సోమ్మే) నది సొమ్మే (నది) దగ్గర మొదలవుతుంది.<ref name="dbpedia_link" />ఈ నది [[సొమ్మే (నది)]]లో కలుస్తుంది. <ref name="dbpedia_link" />
#
# ==సముద్రంలో నీటి విడుదల==
#
#
# ==మూలాలు==
# <references />
#
# [[వర్గం:నదులు]][[వర్గం:https://en.wikipedia.org/wiki/Nievre_(Somme)నదులు]]
#  [[వర్గం:http://dbpedia.org/resource/Nievre_(Somme)నదులు]]
#
#
# [[వర్గం:తెవికీ నదులు]]
#
#  27133 నియెవ్రే (సోమ్మే)

# %%
import string
from hashlib import sha1
from datetime import datetime
import pandas as pd
from jinja2 import Environment, FileSystemLoader,Template
## Change below siteinfo if different website is picked ##
tewiki = '''<mediawiki xmlns="http://www.mediawiki.org/xml/export-0.10/" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.mediawiki.org/xml/export-0.10/ http://www.mediawiki.org/xml/export-0.10.xsd" version="0.10" xml:lang="te">
	<siteinfo>
		<sitename>tewiki</sitename>
		<dbname>indicwiki</dbname>
		<base>https://tewiki.iiit.ac.in/index.php/%E0%B0%AE%E0%B1%8A%E0%B0%A6%E0%B0%9F%E0%B0%BF_%E0%B0%AA%E0%B1%87%E0%B0%9C%E0%B1%80</base>
		<generator>MediaWiki 1.34.0</generator>
		<case>first-letter</case>
		<namespaces>
			<namespace key="-2" case="first-letter">మీడియా</namespace>
			<namespace key="-1" case="first-letter">ప్రత్యేక</namespace>
			<namespace key="0" case="first-letter" />
			<namespace key="1" case="first-letter">చర్చ</namespace>
			<namespace key="2" case="first-letter">వాడుకరి</namespace>
			<namespace key="3" case="first-letter">వాడుకరి చర్చ</namespace>
			<namespace key="4" case="first-letter">Project</namespace>
			<namespace key="5" case="first-letter">Project చర్చ</namespace>
			<namespace key="6" case="first-letter">దస్త్రం</namespace>
			<namespace key="7" case="first-letter">దస్త్రంపై చర్చ</namespace>
			<namespace key="8" case="first-letter">మీడియావికీ</namespace>
			<namespace key="9" case="first-letter">మీడియావికీ చర్చ</namespace>
			<namespace key="10" case="first-letter">మూస</namespace>
			<namespace key="11" case="first-letter">మూస చర్చ</namespace>
			<namespace key="12" case="first-letter">సహాయం</namespace>
			<namespace key="13" case="first-letter">సహాయం చర్చ</namespace>
			<namespace key="14" case="first-letter">వర్గం</namespace>
			<namespace key="15" case="first-letter">వర్గం చర్చ</namespace>
			<namespace key="828" case="first-letter">మాడ్యూల్</namespace>
			<namespace key="829" case="first-letter">మాడ్యూల్ చర్చ</namespace>
			<namespace key="2300" case="first-letter">Gadget</namespace>
			<namespace key="2301" case="first-letter">Gadget talk</namespace>
			<namespace key="2302" case="case-sensitive">Gadget definition</namespace>
			<namespace key="2303" case="case-sensitive">Gadget definition talk</namespace>
			<namespace key="2600" case="first-letter">Topic</namespace>
		</namespaces>
	</siteinfo>\n'''

# 300000 - 350000 => school's articles
# Global Variables
page_id = 1500001

user_id = "19051"
username ="Srihitha"

# Funtions to write page to file object
def sha36(page_id):
	page_id = str(page_id).encode('utf-8')
	sha16 =sha1(page_id).hexdigest()
	sha10 =int(sha16, 16)

	chars =[]
	alphabets = string.digits +string.ascii_lowercase
	while sha10>0:
		sha10, r = divmod(sha10, 36)
		chars.append(alphabets[r])
	
	return ''.join(reversed(chars))

def writePage(title, wikiText, fobj):
	global user_id, username

	pglen = len(wikiText)
	time =datetime.now().strftime("%Y-%m-%dT%H-%M-%SZ")
	
	curPage ='''\n\n
	<page>
		<title>''' +title +'''</title>
		<ns>0</ns>
		<id>''' +str(page_id) +'''</id>
		<revision>
			<id>''' +str(page_id) +'''</id>
			<timestamp>'''+time+'''</timestamp>
			<contributor>
				<username>''' +username +'''</username>
				<id>''' +str(user_id) +'''</id>
			</contributor>
			<comment>xmlpage created</comment>
			<model>wikitext</model>
			<format>text/x-wiki</format>
			<text xml:space="preserve" bytes="''' +str(pglen) +'''">
			\n''' +wikiText +'''
			</text>
			<sha1>''' +sha36(page_id) +'''</sha1>
		</revision>
	</page>
	\n\n'''

	fobj.write(curPage)
	return


def getData(row,i):
	title = row['name_x']
	data = row.to_dict('index')

	return data[i]

file_loader = FileSystemLoader('')
env = Environment(loader=file_loader)
template = env.get_template('Rivers_template_f - Copy.j2')
data = pd.read_excel('mergedata(4).xlsx').astype('str') 
ids = data['rivername'].tolist()
fobj = open('FinalXML.xml', 'w')
fobj.write(tewiki+'\n')

for i, Id in enumerate(ids):
	row = data.loc[data['rivername']==Id]
	title = row['rivername'].values[0]
	text =template.render(getData(row,i))
	writePage(title, text, fobj)
	page_id += 1

fobj.write('</mediawiki>')
fobj.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-04c922404b0d> in <module>()
#     104 env = Environment(loader=file_loader)
#     105 template = env.get_template('Rivers_template_f - Copy.j2')
# --> 106 data = pd.read_excel('mergedata(4).xlsx').astype('str')
#     107 ids = data['rivername'].tolist()
#     108 fobj = open('FinalXML.xml', 'w')
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     362     if not isinstance(io, ExcelFile):
#     363         should_close = True
# --> 364         io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     365     elif engine and engine != io.engine:
#     366         raise ValueError(
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/excel/_base.py in __init__(self, path_or_buffer, engine, storage_options)
#    1190             else:
#    1191                 ext = inspect_excel_format(
# -> 1192                     content_or_path=path_or_buffer, storage_options=storage_options
#    1193                 )
#    1194                 if ext is None:
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/excel/_base.py in inspect_excel_format(content_or_path, storage_options)
#    1069
#    1070     with get_handle(
# -> 1071         content_or_path, "rb", storage_options=storage_options, is_text=False
#    1072     ) as handle:
#    1073         stream = handle.handle
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     709         else:
#     710             # Binary mode
# --> 711             handle = open(handle, ioargs.mode)
#     712         handles.append(handle)
#     713
#
# FileNotFoundError: [Errno 2] No such file or directory: 'mergedata(4).xlsx'

# %%
file_loader = FileSystemLoader('')
env = Environment(loader=file_loader)
template = env.get_template('Rivers_template_f - Copy.j2')
data = pd.read_excel('finalmergedata.xlsx').astype('str') 
ids = data['rivername'].tolist()
print(ids)
fobj = open(f'sample.xml', 'w')
fobj.write(tewiki+'\n')
for i, Id in enumerate(ids):
  row = data.loc[data['rivername']==Id]
  title = row['rivername'].values[0]
  text =template.render(getData(row))
  print(text)
  writePage(title, text, fobj)
  print('\n', i, title)

fobj.write('</mediawiki>')
fobj.close()
# Out:
# Streaming output truncated to the last 5000 lines.
#  [[వర్గం:http://dbpedia.org/resource/Amurనదులు]]
#
#
# [[వర్గం:తెవికీ నదులు]]
#
#  80 అముర్
# {'river_name': 'Ebola ', 'rivername': 'ఎబోలా', 'length': '250.0', 'mouthplace - eng': 'nan', 'mouthplace': 'nan', 'rivermouth - eng': 'Mongala River', 'mouth': 'మంగల నది', 'mouthlocation - eng': 'nan', 'mouthlocation': 'nan', 'source1Location - eng': 'nan', 'source1location': 'nan', 'geometry - eng': 'POINT(20.960556030273 3.3233332633972)', 'latitude': '3.32333', 'longitude': '20.9606', 'subdivision - eng': 'Democratic Republic of the Congo', 'discharge1Location - eng': 'nan', 'discharge_location': 'nan', 'tributariesLeft - eng': 'nan', 'tributariesleft': 'nan', 'tributariesRight - eng': 'nan', 'tributariesright': 'nan', 'othernames - eng': 'nan', 'othernames': 'nan', 'source - eng': 'nan', 'source': 'nan', 'discharge2Location - eng': 'nan', 'discharge2Location': 'nan', 'thumbnail - eng': 'Rio ebola.png?width=300', 'wikiPageWikiLink - eng': 'Ebola, Ngbandi language, Mongala River, Peter Piot, Yambuku, Zaire ebolavirus, Ebolavirus, Congo River, Democratic Republic of the Congo, River source', 'dbpedia_link': 'http://dbpedia.org/resource/Ebola_River', 'wikipedia_link': 'https://en.wikipedia.org/wiki/Ebola_River', 'river name - eng': '  Ebola   ', 'Country - eng': '  Democratic Republic of the Congo  ', 'country': 'డెమొక్రాటిక్ రిపబ్లిక్ ఆఫ్ ద కాంగో', 'State - eng': 'nan', 'states': 'nan', 'Region - eng': 'nan', 'region': 'nan', 'Basin size - eng': 'nan', 'basinsize': 'nan', 'Source-elevation - eng': 'nan', 'sourceelevation': 'nan', 'Discharge-average - eng': 'nan', 'discharge_average': 'nan', 'Discharge-minimum - eng': 'nan', 'discharge_min': 'nan', 'Discharge-maximum - eng': 'nan', 'discharge_max': 'nan', 'Mouth-elevation - eng': 'nan', 'mouthelevation': 'nan', 'map': 'nan', 'Image_url': 'nan'}
#
#
#
#
#
# {{Infobox river
# | name = ఎబోలా
# | subdivision_type1  = దేశం
# | subdivision_name1  = డెమొక్రాటిక్ రిపబ్లిక్ ఆఫ్ ద కాంగో
# | length=250.0 కి.మీ.
# | mouth= మంగల నది
# }}
#     ఎబోలా నది [[డెమొక్రాటిక్ రిపబ్లిక్ ఆఫ్ ద కాంగో]] దేశానికి చెందినది.ఎబోలా నది 250.0 కిలోమీటర్లు పొడవు ఉంటుంది.<ref name="wiki_link">{{Cite web|url=https://en.wikipedia.org/wiki/Ebola_River|title=Ebola |work=Wikipedia |language=en |access-date=2022-06-21}}</ref>
#
# ==భౌగోళిక ప్రదేశం(ప్రాంతం)==
#
# ఎబోలా నది అక్షాంశం(లాటిట్యూడ్) 3.32333, రేఖాంశం(లాంగిట్యూడ్) 20.9606.<ref name="dbpedia_link">{{Cite web|url=http://dbpedia.org/resource/Ebola_River|title=About: |last=|first=|date=|website=dbpedia.org|url-status=live|archive-url=|archive-date=|access-date=2022-06-24}}</ref>
#
# ==నది ప్రవాహం==
#
# ఈ నది [[మంగల నది]]లో కలుస్తుంది. <ref name="dbpedia_link" />
#
# ==సముద్రంలో నీటి విడుదల==
#
#
# ==మూలాలు==
# <references />
#
# [[వర్గం:నదులు]][[వర్గం:https://en.wikipedia.org/wiki/Ebola_Riverనదులు]]
#  [[వర్గం:http://dbpedia.org/resource/Ebola_Riverనదులు]]
#
#
# [[వర్గం:తెవికీ నదులు]]
#
#  81 ఎబోలా
# {'river_name': 'Savinja', 'rivername': 'సావింజ', 'length': '101.8', 'mouthplace - eng': 'Sava', 'mouthplace': 'సావా', 'rivermouth - eng': 'nan', 'mouth': 'nan', 'mouthlocation - eng': 'Sava', 'mouthlocation': 'సావా', 'source1Location - eng': 'Rinka Falls', 'source1location': 'రింకా జలపాతం', 'geometry - eng': 'POINT(15.171999931335 46.083801269531)', 'latitude': '46.0838', 'longitude': '15.172', 'subdivision - eng': 'Slovenia', 'discharge1Location - eng': 'nan', 'discharge_location': 'nan', 'tributariesLeft - eng': 'nan', 'tributariesleft': 'nan', 'tributariesRight - eng': 'nan', 'tributariesright': 'nan', 'othernames - eng': 'nan', 'othernames': 'nan', 'source - eng': 'nan', 'source': 'nan', 'discharge2Location - eng': 'nan', 'discharge2Location': 'nan', 'thumbnail - eng': 'Celje Savinja 001.jpg?width=300', 'wikiPageWikiLink - eng': 'River, File:ZidaniMost1914.jpg, Dreta, Slovenian Environment Agency, Kamnik–Savinja Alps, Luce, Nazarje, Raft, Hydronym, Veliko sirje, Hudinja (river), Flood, Celje, German language, Ljubno ob Savinji, Lasko, smartno ob Paki, Voglajna, Loznica, Medlog, Tributary, Solcava, Paka (river), Rinka Falls, Radmirje, Boris Kalin, Encyclopædia Britannica Eleventh Edition, Slovenia, Sava, Litija, Zidani Most, Letus, File:Slap Rinka 2.JPG, Logar Valley (Sloveni, Natural heritage, Sava', 'dbpedia_link': 'http://dbpedia.org/resource/Category:Savinja', 'wikipedia_link': 'https://en.wikipedia.org/wiki/Savinja', 'river name - eng': '  Savinja  ', 'Country - eng': '  Slovenia  ', 'country': 'స్లోవేనియా', 'State - eng': 'nan', 'states': 'nan', 'Region - eng': 'nan', 'region': 'nan', 'Basin size - eng': '  1,848 km2 (714 sq mi)  1   ', 'basinsize': '1,848 చదరపు కిలోమీటర్లు (714 చదరపు మైళ్ళు)', 'Source-elevation - eng': '  1,310 m (4,300 ft)  1   ', 'sourceelevation': '1,310 మీటర్లు (4,300 అడుగులు)', 'Discharge-average - eng': 'nan', 'discharge_average': 'nan', 'Discharge-minimum - eng': 'nan', 'discharge_min': 'nan', 'Discharge-maximum - eng': 'nan', 'discharge_max': 'nan', 'Mouth-elevation - eng': 'nan', 'mouthelevation': 'nan', 'map': 'nan', 'Image_url': 'nan'}
#
#
#
#
#
# {{Infobox river
# | name = సావింజ
# | subdivision_type1  = దేశం
# | subdivision_name1  = స్లోవేనియా
# | length=101.8 కి.మీ.
# | source1_location = రింకా జలపాతం
# | source1_elevation =1,310 మీటర్లు (4,300 అడుగులు) కి.మీ.
# | mouth_location = సావా
# | basin_size = 1,848 చదరపు కిలోమీటర్లు (714 చదరపు మైళ్ళు)
# }}
#     సావింజ నది [[స్లోవేనియా]] దేశమునకు చెందినది.సావింజ నది పొడవు 101.8 కిలోమీటర్లు. <ref name="wiki_link">{{Cite web|url=https://en.wikipedia.org/wiki/Savinja|title=Savinja|work=Wikipedia |language=en |access-date=2022-06-21}}</ref>
#
# ==భౌగోళిక ప్రదేశం(ప్రాంతం)==
#
# సావింజ నది పరీవాహక ప్రాంతం 1,848 చదరపు కిలోమీటర్లు (714 చదరపు మైళ్ళు) చదరపు కిలోమీటర్లు.<ref name="wiki_link" />సావింజ నది అక్షాంశం(లాటిట్యూడ్) 46.0838, రేఖాంశం(లాంగిట్యూడ్) 15.172.<ref name="dbpedia_link">{{Cite web|url=http://dbpedia.org/resource/Category:Savinja|title=About: |last=|first=|date=|website=dbpedia.org|url-status=live|archive-url=|archive-date=|access-date=2022-06-24}}</ref>
#
# ==నది ప్రవాహం==
#
# సావింజ నది [[స్లోవేనియా]]లోని రింకా జలపాతం దగ్గర మొదలవుతుంది.<ref name="dbpedia_link" />ఈ నది మూలం ఎత్తు 1,310 మీటర్లు (4,300 అడుగులు).<ref name="wiki_link" />ఈ నది సావా దగ్గర సముద్రంలో కలుస్తుంది.<ref name="dbpedia_link" />
# ==మూలాలు==
# <references />
#
# [[వర్గం:నదులు]][[వర్గం:https://en.wikipedia.org/wiki/Savinjaనదులు]]
#  [[వర్గం:http://dbpedia.org/resource/Category:Savinjaనదులు]]
#
#
# [[వర్గం:తెవికీ నదులు]]
#
#  82 సావింజ
# {'river_name': 'Back  (Nunavut)', 'rivername': 'బాక్ (నునావుట్)', 'length': '974.0', 'mouthplace - eng': 'Kitikmeot Region, Nunavut', 'mouthplace': 'కిటిక్\u200cమీట్ ప్రాంతం, నునావట్', 'rivermouth - eng': 'Arctic Ocean, Chantrey Inlet', 'mouth': 'ఆర్కిటిక్ మహాసముద్రం, చాంట్రే ఇన్లెట్', 'mouthlocation - eng': 'Kitikmeot Region, Nunavut', 'mouthlocation': 'కిటిక్\u200cమీట్ ప్రాంతం, నునావట్', 'source1Location - eng': 'North Slave Region, Northwest Territories', 'source1location': 'నార్త్ స్లేవ్ రీజియన్, నార్త్ వెస్ట్ టెరిటరీలు', 'geometry - eng': 'POINT(-108.03555297852 64.72721862793)', 'latitude': '64.7272', 'longitude': '-108.036', 'subdivision - eng': 'Nunavut & Northwest Territories, Canada', 'discharge1Location - eng': 'nan', 'discharge_location': 'nan', 'tributariesLeft - eng': 'nan', 'tributariesleft': 'nan', 'tributariesRight - eng': 'nan', 'tributariesright': 'nan', 'othernames - eng': 'Great Fish River', 'othernames': 'గ్రేట్ ఫిష్ నది', 'source - eng': 'Unnamed lake', 'source': 'పేరులేని సరస్సు', 'discharge2Location - eng': 'nan', 'discharge2Location': 'nan', 'thumbnail - eng': 'Back River (July 2006).jpg?width=300', 'wikiPageWikiLink - eng': 'Kayak, Wolf, Bush plane, Haningayogmiut, Kazan River, Chantrey Inlet, Yellowknife, Gjoa Haven, Baker Lake, Nunavut, Garry Lake, Back River volcanic complex, Rapids, United States, John Ross (Royal Navy officer), Anseriformes, North Slave Region, File:Garry Lake in August 2006.jpg, Canoeing, Utkuhiksalik, Copper Inuit, Wildlife, Hypothermia, Coppermine River, Tree line, Yellowknives, Northwest Passage, Arctic Ocean, List of rivers of the Northwest Territories, Dogrib language, Dubawnt Lake, Natural Resources Canada, Caribou Inuit, Hood River (Nunavut), Northwest Territories, Muskox, Chipewyan, Hudsons Bay Company, Northern Canada, Arctic, Gale, Bear spray, George Back, Thelon River, Tributary, Kitikmeot Region, Kivalliq Region, Atlas of Canada, Arctic Circle, Montreal Island (Nunavut), Brown bear, Inuit, Canoe, Thelon Wildlife Sanctuary, Jean Briggs, List of rivers of Nunavut, Polar bear, Canada goose, Ahiagmiut, United Kingdom, Arctic hare, Lake Beechey, Portage, Important Bird Area, List of longest rivers of Canada, Spray deck, Floatplane, Snow goose, Hayes River (Nunavut), John Franklin, File:Head of the Back Rivers Escape Rapids in August 2006.jpg, Reindeer, Nunavut, Wolverine, Canadian Broadcasting Corporation, Inuktitut, Kaernermiut', 'dbpedia_link': 'http://dbpedia.org/resource/Back_River_(Nunavut)', 'wikipedia_link': 'https://en.wikipedia.org/wiki/Back_River_(Nunavut)', 'river name - eng': '  Back  (Nunavut)  ', 'Country - eng': '  Canada  ', 'country': 'కెనడా', 'State - eng': 'nan', 'states': 'nan', 'Region - eng': 'nan', 'region': 'nan', 'Basin size - eng': '  106,500 km2 (41,100 sq mi)  ', 'basinsize': '106,500 చదరపు కిలోమీటర్లు (41,100 చదరపు మైళ్ళు)', 'Source-elevation - eng': '  382 m (1,253 ft)  ', 'sourceelevation': '382 మీటర్లు (1,253 అడుగులు)', 'Discharge-average - eng': '  612 m3/s (21,600 cu ft/s)  ', 'discharge_average': '612 ఘనపు మీటర్/సెకండ్ (21,600 ఘనపు అడుగులు/సెకండ్)', 'Discharge-minimum - eng': 'nan', 'discharge_min': 'nan', 'Discharge-maximum - eng': 'nan', 'discharge_max': 'nan', 'Mouth-elevation - eng': '  0 m (0 ft)  ', 'mouthelevation': '0 మీటర్లు (0 అడుగులు)', 'map': 'nan', 'Image_url': 'nan'}
#
#
#
#
#
# {{Infobox river
# | name = బాక్ (నునావుట్)
# | subdivision_type1  = దేశం
# | subdivision_name1  = కెనడా
# | length=974.0 కి.మీ.
# | discharge1_avg = 612 ఘనపు మీటర్/సెకండ్ (21,600 ఘనపు అడుగులు/సెకండ్)
# | source1 = పేరులేని సరస్సు
# | source1_location = నార్త్ స్లేవ్ రీజియన్, నార్త్ వెస్ట్ టెరిటరీలు
# | source1_elevation =382 మీటర్లు (1,253 అడుగులు) కి.మీ.
# | mouth= ఆర్కిటిక్ మహాసముద్రం, చాంట్రే ఇన్లెట్
# | mouth_location = కిటిక్‌మీట్ ప్రాంతం, నునావట్
# | mouth_elevation =0 మీటర్లు (0 అడుగులు) కి.మీ.
# | basin_size = 106,500 చదరపు కిలోమీటర్లు (41,100 చదరపు మైళ్ళు)
# }}
#     బాక్ (నునావుట్) నది [[కెనడా]] దేశమునకు చెందినది.బాక్ (నునావుట్) నదిని గ్రేట్ ఫిష్ నది అని కూడా పిలుస్తారు.ఈ నది పొడవు 974.0కిలోమీటర్లు.<ref name="wiki_link">{{Cite web|url=https://en.wikipedia.org/wiki/Back_River_(Nunavut)|title=Back  (Nunavut)|work=Wikipedia |language=en |access-date=2022-06-21}}</ref>
#
# ==భౌగోళిక ప్రదేశం(ప్రాంతం)==
#
# బాక్ (నునావుట్) నది 106,500 చదరపు కిలోమీటర్లు (41,100 చదరపు మైళ్ళు) చదరపు కిలోమీటర్ల పరీవాహక ప్రాంతం కలిగి ఉంటుంది.<ref name="wiki_link" />ఈ నది అక్షాంశం(లాటిట్యూడ్) 64.7272, రేఖాంశం(లాంగిట్యూడ్) -108.036.<ref name="dbpedia_link">{{Cite web|url=http://dbpedia.org/resource/Back_River_(Nunavut)|title=About: |last=|first=|date=|website=dbpedia.org|url-status=live|archive-url=|archive-date=|access-date=2022-06-24}}</ref>
#
# ==నది ప్రవాహం==
#
# బాక్ (నునావుట్) నది కెనడాలోని పేరులేని సరస్సులోని నార్త్ స్లేవ్ రీజియన్, నార్త్ వెస్ట్ టెరిటరీలు దగ్గర మొదలవుతుంది.<ref name="dbpedia_link" />ఈ నది మూలం ఎత్తు 382 మీటర్లు (1,253 అడుగులు).<ref name="wiki_link" />బాక్ (నునావుట్) నది కిటిక్‌మీట్ ప్రాంతం, నునావట్ దగ్గర [[ఆర్కిటిక్ మహాసముద్రం, చాంట్రే ఇన్లెట్]]లో కలుస్తుంది.<ref name="dbpedia_link" />ఈ నది 0 మీటర్లు (0 అడుగులు) ఎత్తునుంచి సముద్రంలో కలుస్తుంది.<ref name="wiki_link" />
#
# ==సముద్రంలో నీటి విడుదల==
#
# బాక్ (నునావుట్) నది లోని నీరు క్షణముకు సగటు 612 ఘనపు మీటర్/సెకండ్ (21,600 ఘనపు అడుగులు/సెకండ్).<ref name="wiki_link" />
# ==మూలాలు==
# <references />
#
# [[వర్గం:నదులు]][[వర్గం:https://en.wikipedia.org/wiki/Back_River_(Nunavut)నదులు]]
#  [[వర్గం:http://dbpedia.org/resource/Back_River_(Nunavut)నదులు]]
#
#
# [[వర్గం:తెవికీ నదులు]]
#
#  83 బాక్ (నునావుట్)
# {'river_name': ' Parrett', 'rivername': 'పారెట్', 'length': '59.5457', 'mouthplace - eng': 'Burnham-on-Sea, England, Somerset, Sedgemoor', 'mouthplace': 'బర్న్\u200cహామ్-ఆన్-సీ, ఇంగ్లాండ్, సోమర్\u200cసెట్, సెడ్జ్\u200cమూర్', 'rivermouth - eng': 'Bridgwater Bay', 'mouth': 'బ్రిడ్జ్వాటర్ బే', 'mouthlocation - eng': 'Burnham-on-Sea, England, Somerset, Sedgemoor', 'mouthlocation': 'బర్న్\u200cహామ్-ఆన్-సీ, ఇంగ్లాండ్, సోమర్\u200cసెట్, సెడ్జ్\u200cమూర్', 'source1Location - eng': 'England, Dorset', 'source1location': 'ఇంగ్లాండ్, డోర్సెట్', 'geometry - eng': 'POINT(-2.7327778339386 50.846668243408)', 'latitude': '50.8467', 'longitude': '-2.73278', 'subdivision - eng': 'Somerset Levels', 'discharge1Location - eng': 'Chiselborough', 'discharge_location': 'చిసెల్బరో', 'tributariesLeft - eng': 'Cannington Brook', 'tributariesleft': 'కానింగ్టన్ బ్రూక్', 'tributariesRight - eng': 'River Tone', 'tributariesright': 'నది టోన్', 'othernames - eng': 'nan', 'othernames': 'nan', 'source - eng': 'Chedington', 'source': 'చెడింగ్టన్', 'discharge2Location - eng': 'nan', 'discharge2Location': 'nan', 'thumbnail - eng': 'Riverparrett.jpg?width=300', 'wikiPageWikiLink - eng': 'Battle of Peonnum, Deserted medieval village, M5 motorway, Puriton, Severn Tunnel, Dunball, Tidal barrage, Telescopic Bridge, Bridgwater, Wessex Water, 1607 Bristol Channel floods, Bristol–Exeter line, Kiln, File:River Parrett near Pawlett.jpg, Washford River, River Brue, Industrial Revolution, Odontomyia angulata, Scoop wheel, Turnpike trust, Walter of Douai, Great Western Railway, River Cary (Somerset), Alauda, North Petherton, Moat, File:Mudflats at Combwich.jpg, Langport, Salt marsh, Fullers earth, Herepath, File:OathLockRiverParrett.jpg, Odontomyia ornata, Bridgwater, Ceremonial counties of England, Brendon Hills, Combwich, Valvata macrostoma, Brean Down, Ketch, Hamstone, Invertebrate, Limestone, Meander, Bath brick, Glastonbury Abbey, South Petherton, Shoal, Hinkley Point A nuclear power station, Wharf, File:Riverparrettseat.jpg, Bridgwater Castle, Burrow Mump, Bridport Sand Formation, Odda, Ealdorman of Devon, Haselbury Plucknett, Port of Bristol, File:Great Bow Bridge.jpg, Peregrine falcon, Emergency management, Cannington Brook, European Regional Development Fund, Lock (water navigation), Bridgwater and Taunton Canal, Lias Group, Celtic Christianity, Walter Bagehot, Aller, Somerset, Festuca ovina, Stenomicra cogani, Isambard Kingdom Brunel, Muchelney Abbey, Environmentally sensitive area, Brickwork, Kings Sedgemoor Drain, BBC Radio 4, Warehouse, Langport, Westonzoyland Pumping Station Museum, Welsh language, Cartography, Cornish language, Dry dock, Filipendula ulmaria, European Union, Ham Hill, Somerset, Synaptus filiformis, Hinkley Point, John, King of England, Taunton, Roman Empire, Western marsh harrier, Southlake Moor, Huntworth, Inland Waterways Association, A39 road, Roman Britain, Riparian zone, Drovers road, Royal Ordnance Factory, National Farmers Union of England and Wales, A303 road, Biodiversity, Keuper marl, Ship chandler, Axmouth, Borough, File:Southlakemoor.jpg, ROF Bridgwater, Grassland, Ecosystem, West Chinnock, Ivelchester and Langport Navigation, Tilia cordata, River Yeo (South Somerset), Stogursey, Tramway (industrial), Sorbus torminalis, Somerset Buildings Preservation Trust, Meadow, Mudflat, Aller Hill, File:Monksleazeclyce.jpg, File:Burrow Bridge.jpg, Lonchoptera scutellata, Ancient woodland, Pawlett, River Isle, Centrifugal pump, Tufted duck, Northmoor Green, Charles I of England, Sluice, Peat, Burnham-on-Sea, Eurasian whimbrel, River Axe (Lyme Bay), Arable land, File:Dunball Wharf.jpg, Kings Sedgemoor, South West England, Drainage system (agriculture), Eurasian wigeon, Trinity House, Napoleonic Wars, File:BurrowBridgeView2.jpg, James VI and I, Eurasian teal, Pump, Area of archaeological potential, Severn Estuary, Winter flooding of 2013–14 on the Somerset Levels, List of long-distance footpaths in the United Kingdom, Beam engine, Devon, Gristmill, Do ...
#
#
#
#
#
# {{Infobox river
# | name = పారెట్
# | subdivision_type1  = దేశం
# | subdivision_name1  = ఇంగ్లండ్
# | length=59.5457 కి.మీ.
# | discharge1_location= చిసెల్బరో
# | discharge1_min= 2.5 క్యూబిక్ అడుగులు (0.071 క్యూబిక్ మీటర్లు)
# | discharge1_avg = 67.45 ఘనపు అడుగులు/సెకండ్ (1.910 ఘనపు మీటర్/సెకండ్)
# | discharge1_max = 6,109 క్యూబిక్ అడుగులు (173.0 క్యూబిక్ మీటర్లు)
# | source1 = చెడింగ్టన్
# | source1_location = ఇంగ్లాండ్, డోర్సెట్
# | mouth= బ్రిడ్జ్వాటర్ బే
# | mouth_location = బర్న్‌హామ్-ఆన్-సీ, ఇంగ్లాండ్, సోమర్‌సెట్, సెడ్జ్‌మూర్
# | basin_size = 643 చదరపు మైళ్ళు (1,670 చదరపు కిలోమీటర్లు)
# | tributaries_left = కానింగ్టన్ బ్రూక్
# | tributaries_right = నది టోన్
# }}
#     పారెట్ నది [[ఇంగ్లండ్]] దేశమునకు చెందినది.పారెట్ నది పొడవు 59.5457 కిలోమీటర్లు. <ref name="wiki_link">{{Cite web|url=https://en.wikipedia.org/wiki/River_Parrett|title= Parrett|work=Wikipedia |language=en |access-date=2022-06-21}}</ref>
#
# ==భౌగోళిక ప్రదేశం(ప్రాంతం)==
#
# పారెట్ నది పరీవాహక ప్రాంతం 643 చదరపు మైళ్ళు (1,670 చదరపు కిలోమీటర్లు) చదరపు కిలోమీటర్లు.<ref name="wiki_link" />ఈ నది అక్షాంశం(లాటిట్యూడ్) 50.8467, రేఖాంశం(లాంగిట్యూడ్) -2.73278.<ref name="dbpedia_link">{{Cite web|url=http://dbpedia.org/resource/River_Parrett|title=About: |last=|first=|date=|website=dbpedia.org|url-status=live|archive-url=|archive-date=|access-date=2022-06-24}}</ref>
#
# ==నది ఉపనదులు==
#
# పారెట్ నదికి గల ముఖ్యమైన ఉపనదులు కానింగ్టన్ బ్రూక్,నది టోన్.<ref name="dbpedia_link" />
#
# ==నది ప్రవాహం==
#
# [[ఇంగ్లండ్]]లోని చెడింగ్టన్లోని ఇంగ్లాండ్, డోర్సెట్ దగ్గర పారెట్ నది మొదలవుతుంది.<ref name="dbpedia_link" />ఈ నది బర్న్‌హామ్-ఆన్-సీ, ఇంగ్లాండ్, సోమర్‌సెట్, సెడ్జ్‌మూర్ దగ్గర [[బ్రిడ్జ్వాటర్ బే]]లో కలుస్తుంది.<ref name="dbpedia_link" />
#
# ==సముద్రంలో నీటి విడుదల==
#
# పారెట్ నది చిసెల్బరో దగ్గర సముద్రంలో కలుస్తుంది.<ref name="dbpedia_link" />ఈ నది లోని నీరు క్షణముకు సగటు 67.45 ఘనపు అడుగులు/సెకండ్ (1.910 ఘనపు మీటర్/సెకండ్). <ref name="wiki_link" />ఇప్పటి వరకు నమోదు అయినా గరిష్ట మోతాదు క్షణముకు 6,109 క్యూబిక్ అడుగులు (173.0 క్యూబిక్ మీటర్లు).<ref name="wiki_link" />ఇప్పటి వరకు నమోదు అయినా కనిష్ట మోతాదు క్షణముకు 2.5 క్యూబిక్ అడుగులు (0.071 క్యూబిక్ మీటర్లు).<ref name="wiki_link" />
# ==మూలాలు==
# <references />
#
# [[వర్గం:నదులు]][[వర్గం:https://en.wikipedia.org/wiki/River_Parrettనదులు]]
#  [[వర్గం:http://dbpedia.org/resource/River_Parrettనదులు]]
#
#
# [[వర్గం:తెవికీ నదులు]]
#
#  84 పారెట్
# {'river_name': 'Potomac ', 'rivername': 'పోటోమాక్', 'length': '651.784', 'mouthplace - eng': 'Northumberland County, Virginia, United States, St. Marys County, Maryland', 'mouthplace': 'నార్తంబర్\u200cల్యాండ్ కౌంటీ, వర్జీనియా, యునైటెడ్ స్టేట్స్, సెయింట్ మేరీస్ కౌంటీ, మేరీల్యాండ్', 'rivermouth - eng': 'Chesapeake Bay', 'mouth': 'చీసాపీక్ బే', 'mouthlocation - eng': 'Northumberland County, Virginia, United States, St. Marys County, Maryland', 'mouthlocation': 'నార్తంబర్\u200cల్యాండ్ కౌంటీ, వర్జీనియా, యునైటెడ్ స్టేట్స్, సెయింట్. మేరీస్ కౌంటీ, మేరీల్యాండ్', 'source1Location - eng': 'West Virginia', 'source1location': 'వెస్ట్ వర్జీనియా', 'geometry - eng': 'POINT(-79.491111755371 39.195278167725)', 'latitude': '39.1953', 'longitude': '-79.4911', 'subdivision - eng': 'Maryland', 'discharge1Location - eng': 'Little Falls, near Washington, D.C.', 'discharge_location': 'లిటిల్ ఫాల్స్, వాషింగ్టన్, డి.సి సమీపంలో', 'tributariesLeft - eng': 'Anacostia River', 'tributariesleft': 'అనకోస్టియా నది', 'tributariesRight - eng': 'Cacapon River', 'tributariesright': 'కాపాన్ నది', 'othernames - eng': 'nan', 'othernames': 'nan', 'source - eng': 'North Branch Potomac River, South Branch Potomac River', 'source': 'ఉత్తర శాఖ పోటోమాక్ నది, దక్షిణ శాఖ పోటోమాక్ నది', 'discharge2Location - eng': 'Point of Rocks, Maryland', 'discharge2Location': 'పాయింట్ ఆఫ్ రాక్స్, మేరీల్యాండ్', 'thumbnail - eng': 'Great Falls of the Potomac River - NPS.jpg?width=300', 'wikiPageWikiLink - eng': 'Southern red-backed vole, Mummichog, Spring salamander, Jennings Randolph Lake, File:Potomac green water.JPG, Tide, Upland chorus frog, Eastern spadefoot toad, Sheepshead minnow, Rosyface shiner, Green sunfish, White crappie, Longnose dace, Smoke Hole Canyon, Spout Run, Jubal Early, Esox, Southern flying squirrel, Striped bass, Emerald shiner, Greenside darter, Washington, D.C., Catoctin Creek (Virgini, Banded killifish, Common watersnake, Marbled salamander, United States Army Corps of Engineers, Spottail shiner, Blueback herring, River chub, Northern lamprey, Chelydridae, Washington Aqueduct, Long-tailed shrew, File:View of Potomac River from Mount Vernon.jpg, Tuscarora Creek (Potomac River tributary), Phosphorus, Gulf Coast spiny softshell turtle, Power Plant and Dam No. 4, Cougar, Vanderlip, West Virginia, File:Confluence of the Potomac and Shenandoah at Harpers Ferry - aer photo by NPS.jpg, Catostomidae, Least weasel, American shad, Common shiner, Point Lookout State Park, File:View of the Potomac River - George Washington Birthplace National Monument - Stierch - B.jpg, Potomac Riverkeeper, Broad Run (Loudoun County, Virgini, Brown trout, Potomac River basin reservoir projects, Shenandoah River, Carpenter frog, Eastern small-footed myotis, Goldfish, Rock Creek (Potomac River tributary), Northern pike, Stream, Quillback, Ribbon snake, Rock Run (Potomac River tributary), Seneca Dam, Pseudonaja nuchalis, Painted turtle, Elk, Monongahela National Forest, Sleepy Creek, American green tree frog, Breton Bay, Leonardtown, Swallowtail shiner, File:View of Potomac River at Junction of Cacapon River.jpg, Blue Ridge Mountains, Leatherback sea turtle, Pupfish, Green sea turtle, Cabins, West Virginia, Salinity, Centrarchidae, Eastern meadow vole, Appalachian cottontail, Tessellated darter, Meadow jumping mouse, Silver-haired bat, Alexandria, Virginia, Allegheny woodrat, White sucker, Marsh rice rat, File:American Shad by Duane Raver USFWS.jpg, Watts Branch (Potomac River tributary), Supreme Court of the United States, Seal salamander, Occoquan River, Thomas Nast, Woodland jumping mouse, Wicomico River (Potomac River tributary), Long-tailed weasel, Colonial charters in the Thirteen Colonies, Little Monocacy River, United States Congress, South Branch Valley Railroad, Exoglossum maxillingua, George Washington, Preston County, West Virginia, West Virginia, Port Tobacco River, Noturus insignis, White bullhead, Bluegill, Potomac sculpin, Mineral County, West Virginia, Star-nosed mole, Coastal plai ...
#
#
#
#
#
# {{Infobox river
# | name = పోటోమాక్
# | map = Australia_Queensland_relief_location_map.jpg
# | map_size = 300 px
# | map_caption = పోటోమాక్ నది పటం
# | subdivision_type1  = దేశం
# | subdivision_name1  = యునైటెడ్ స్టేట్స్ ఆఫ్ అమెరికా
# | subdivision_type2  = రాష్ట్రం
# | subdivision_name2  = పశ్చిమ వర్జీనియా, మేరీల్యాండ్, వర్జీనియా, డిస్ట్రిక్ట్ ఆఫ్ కొలంబియా
# | length=651.784 కి.మీ.
# | discharge1_location= లిటిల్ ఫాల్స్, వాషింగ్టన్, డి.సి సమీపంలో
# | discharge1_min= 4017 క్యూబిక్ అడుగులు (113.7 క్యూబిక్ మీటర్లు)
# | discharge1_avg = 3,376 ఘనపు అడుగులు/సెకండ్ (95.6 ఘనపు మీటర్/సెకండ్)
# | discharge1_max = 23,760 క్యూబిక్ అడుగులు (673 క్యూబిక్ మీటర్లు)
# | source1 = ఉత్తర శాఖ పోటోమాక్ నది, దక్షిణ శాఖ పోటోమాక్ నది
# | source1_location = వెస్ట్ వర్జీనియా
# | source1_elevation =3,060 అడుగులు (930 మీటర్లు) కి.మీ.
# | mouth= చీసాపీక్ బే
# | mouth_location = నార్తంబర్‌ల్యాండ్ కౌంటీ, వర్జీనియా, యునైటెడ్ స్టేట్స్, సెయింట్. మేరీస్ కౌంటీ, మేరీల్యాండ్
# | mouth_elevation =0 అడుగులు (0 మీటర్లు) కి.మీ.
# | basin_size = 14,700 చదరపు మైళ్ళు (38,000 చదరపు కిలోమీటర్లు)
# | tributaries_left = అనకోస్టియా నది
# | tributaries_right = కాపాన్ నది
# }}
#     పోటోమాక్ నది [[యునైటెడ్ స్టేట్స్ ఆఫ్ అమెరికా]] దేశానికి చెందినది.పశ్చిమ వర్జీనియా, మేరీల్యాండ్, వర్జీనియా, డిస్ట్రిక్ట్ ఆఫ్ కొలంబియా రాష్ట్రాలలో పోటోమాక్ నది ప్రవహిస్తుంది.పోటోమాక్ నది 651.784 కిలోమీటర్లు పొడవు ఉంటుంది.<ref name="wiki_link">{{Cite web|url=https://en.wikipedia.org/wiki/Potomac_River|title=Potomac |work=Wikipedia |language=en |access-date=2022-06-21}}</ref>
#
# ==భౌగోళిక ప్రదేశం(ప్రాంతం)==
#
# పోటోమాక్ నది 14,700 చదరపు మైళ్ళు (38,000 చదరపు కిలోమీటర్లు) చదరపు కిలోమీటర్ల పరీవాహక ప్రాంతం కలిగి ఉంటుంది.<ref name="wiki_link" />పోటోమాక్ నది అక్షాంశం(లాటిట్యూడ్) 39.1953, రేఖాంశం(లాంగిట్యూడ్) -79.4911.<ref name="dbpedia_link">{{Cite web|url=http://dbpedia.org/resource/Potomac_River|title=About: |last=|first=|date=|website=dbpedia.org|url-status=live|archive-url=|archive-date=|access-date=2022-06-24}}</ref>
#
# ==నది ఉపనదులు==
#
# పోటోమాక్ నదికి గల ముఖ్యమైన ఉపనదులు అనకోస్టియా నది,కాపాన్ నది.<ref name="dbpedia_link" />
#
# ==నది ప్రవాహం==
#
# [[యునైటెడ్ స్టేట్స్ ఆఫ్ అమెరికా]]లోని ఉత్తర శాఖ పోటోమాక్ నది, దక్షిణ శాఖ పోటోమాక్ నదిలోని వెస్ట్ వర్జీనియా దగ్గర పోటోమాక్ నది మొదలవుతుంది.<ref name="dbpedia_link" />ఈ నది మూలం ఎత్తు 3,060 అడుగులు (930 మీటర్లు).<ref name="wiki_link" />ఈ నది నార్తంబర్‌ల్యాండ్ కౌంటీ, వర్జీనియా, యునైటెడ్ స్టేట్స్, సెయింట్. మేరీస్ కౌంటీ, మేరీల్యాండ్ దగ్గర [[చీసాపీక్ బే]]లో కలుస్తుంది.<ref name="dbpedia_link" />ఈ నది 0 అడుగులు (0 మీటర్లు) ఎత్తునుంచి సముద్రంలో కలుస్తుంది.<ref name="wiki_link" />
#
# ==సముద్రంలో నీటి విడుదల==
#
# పోటోమాక్ నది సముద్రంలో కలిసే స్థలం లిటిల్ ఫాల్స్, వాషింగ్టన్, డి.సి సమీపంలో.<ref name="dbpedia_link" />ఈ నది లోని నీరు క్షణముకు సగటు 3,376 ఘనపు అడుగులు/సెకండ్ (95.6 ఘనపు మీటర్/సెకండ్). <ref name="wiki_link" /> ఇప్పటి వరకు నమోదు అయినా రికార్డుల ప్రకారం పోటోమాక్ నది లోని నీరు క్షణముకు గరిష్ట మోతాదు 23,760 క్యూబిక్ అడుగులు (673 క్యూబిక్ మీటర్లు).<ref name="wiki_link" />ఇప్పటి వరకు నమోదు అయినా కనిష్ట మోతాదు క్షణముకు 4017 క్యూబిక్ అడుగులు (113.7 క్యూబిక్ మీటర్లు).<ref name="wiki_link" />
# ==మూలాలు==
# <references />
#
# [[వర్గం:నదులు]][[వర్గం:https://en.wikipedia.org/wiki/Potomac_Riverనదులు]]
#  [[వర్గం:http://dbpedia.org/resource/Potomac_Riverనదులు]]
#
#
# [[వర్గం:తెవికీ నదులు]]
#
#  85 పోటోమాక్
# {'river_name': 'Vedea', 'rivername': 'వేడియా', 'length': '224.0', 'mouthplace - eng': 'Bujoru, Teleorman', 'mouthplace': 'బుజోరు, టెలియోర్మాన్', 'rivermouth - eng': 'Danube', 'mouth': 'డానుబే', 'mouthlocation - eng': 'Bujoru, Teleorman', 'mouthlocation': 'బుజోరు, టెలియోర్మాన్', 'source1Location - eng': 'Cotmeana Plateau', 'source1location': 'కోట్మీనా పీఠభూమి', 'geometry - eng': 'POINT(25.526388168335 43.653610229492)', 'latitude': '43.6536', 'longitude': '25.5264', 'subdivision - eng': 'Roshiorii de Vede, Alexandria, Romania, Teleorman County, Romania, Argesh County, Olt County', 'discharge1Location - eng': 'nan', 'discharge_location': 'nan', 'tributariesLeft - eng': 'Teleorman (river)', 'tributariesleft': 'టెలియోర్మాన్ (నది)', 'tributariesRight - eng': 'nan', 'tributariesright': 'nan', 'othernames - eng': 'nan', 'othernames': 'nan', 'source - eng': 'Daduleshti Hill', 'source': 'దాదులేష్టి కొండ', 'discharge2Location - eng': 'nan', 'discharge2Location': 'nan', 'thumbnail - eng': 'Vedea.River.1.jpg?width=300', 'wikiPageWikiLink - eng': 'Mavrodin, Roshiorii de Vede, Cotmeana (river), Alexandria, Romania, Argesh County, Nicolae Titulescu, Olt, Contzeshti, Teleorman, Cotmeana Plateau, Corbu, Olt, Optashi-Magura, Tecuci (river), Branceni, Dorofei (river), Burdea, Daduleshti Hill, Tatuleshti, Bujoru, Teleorman, Veditza, Romania, Plosca, Paraul Cainelui, Buzescu, Izvoarele (Vede, Bragadiru, Teleorman, Teleorman County, Stejaru, Teleorman, Teleorman (river), Plapcea, Poroschia, Dacian language, Danube, Cervenia, Valeni, Olt, Spineni, Peretu, Fagetzelu, Bratcov, Vedea, Teleorman, Smardioasa, Nanov (river), Cioraca, Olt County', 'dbpedia_link': 'http://dbpedia.org/resource/Vedea', 'wikipedia_link': 'https://en.wikipedia.org/wiki/Vedea', 'river name - eng': '  Vedea  ', 'Country - eng': '  Romania  ', 'country': 'రొమేనియా', 'State - eng': 'nan', 'states': 'nan', 'Region - eng': 'nan', 'region': 'nan', 'Basin size - eng': '  5,430 km2 (2,100 sq mi)  ', 'basinsize': '5,430 చదరపు కిలోమీటర్లు (2,100 చదరపు మైళ్ళు)', 'Source-elevation - eng': '  435 m (1,427 ft)  ', 'sourceelevation': '435 మీటర్లు (1,427 అడుగులు)', 'Discharge-average - eng': 'nan', 'discharge_average': 'nan', 'Discharge-minimum - eng': 'nan', 'discharge_min': 'nan', 'Discharge-maximum - eng': 'nan', 'discharge_max': 'nan', 'Mouth-elevation - eng': '  20 m (66 ft)  ', 'mouthelevation': '20 మీటర్లు (66 అడుగులు)', 'map': 'nan', 'Image_url': 'nan'}
#
#
#
#
#
# {{Infobox river
# | name = వేడియా
# | subdivision_type1  = దేశం
# | subdivision_name1  = రొమేనియా
# | length=224.0 కి.మీ.
# | source1 = దాదులేష్టి కొండ
# | source1_location = కోట్మీనా పీఠభూమి
# | source1_elevation =435 మీటర్లు (1,427 అడుగులు) కి.మీ.
# | mouth= డానుబే
# | mouth_location = బుజోరు, టెలియోర్మాన్
# | mouth_elevation =20 మీటర్లు (66 అడుగులు) కి.మీ.
# | basin_size = 5,430 చదరపు కిలోమీటర్లు (2,100 చదరపు మైళ్ళు)
# | tributaries_left = టెలియోర్మాన్ (నది)
# }}
#     వేడియా నది [[రొమేనియా]] దేశానికి చెందినది.వేడియా నది 224.0 కిలోమీటర్లు పొడవు ఉంటుంది.<ref name="wiki_link">{{Cite web|url=https://en.wikipedia.org/wiki/Vedea|title=Vedea|work=Wikipedia |language=en |access-date=2022-06-21}}</ref>
#
# ==భౌగోళిక ప్రదేశం(ప్రాంతం)==
#
# వేడియా నది 5,430 చదరపు కిలోమీటర్లు (2,100 చదరపు మైళ్ళు) చదరపు కిలోమీటర్ల పరీవాహక ప్రాంతం కలిగి ఉంటుంది.<ref name="wiki_link" />వేడియా నది అక్షాంశం(లాటిట్యూడ్) 43.6536, రేఖాంశం(లాంగిట్యూడ్) 25.5264.<ref name="dbpedia_link">{{Cite web|url=http://dbpedia.org/resource/Vedea|title=About: |last=|first=|date=|website=dbpedia.org|url-status=live|archive-url=|archive-date=|access-date=2022-06-24}}</ref>
#
# ==నది ఉపనదులు==
#
# టెలియోర్మాన్ (నది),nan మొదలగునవి వేడియా నదికి ముఖ్యమైన ఉపనదులు.<ref name="dbpedia_link" />
#
# ==నది ప్రవాహం==
#
# వేడియా నది రొమేనియాలోని దాదులేష్టి కొండలోని కోట్మీనా పీఠభూమి దగ్గర మొదలవుతుంది.<ref name="dbpedia_link" />ఈ నది మూలం ఎత్తు 435 మీటర్లు (1,427 అడుగులు).<ref name="wiki_link" />వేడియా నది బుజోరు, టెలియోర్మాన్ దగ్గర [[డానుబే]]లో కలుస్తుంది.<ref name="dbpedia_link" />ఈ నది 20 మీటర్లు (66 అడుగులు) ఎత్తునుంచి సముద్రంలో కలుస్తుంది.<ref name="wiki_link" />
#
# ==సముద్రంలో నీటి విడుదల==
#
#
# ==మూలాలు==
# <references />
#
# [[వర్గం:నదులు]][[వర్గం:https://en.wikipedia.org/wiki/Vedeaనదులు]]
#  [[వర్గం:http://dbpedia.org/resource/Vedeaనదులు]]
#
#
# [[వర్గం:తెవికీ నదులు]]
#
#  86 వేడియా
# {'river_name': 'Kerio ', 'rivername': 'కెరియో', 'length': 'nan', 'mouthplace - eng': 'nan', 'mouthplace': 'nan', 'rivermouth - eng': 'nan', 'mouth': 'nan', 'mouthlocation - eng': 'nan', 'mouthlocation': 'nan', 'source1Location - eng': 'nan', 'source1location': 'nan', 'geometry - eng': 'POINT(35.709644317627 0.52858102321625)', 'latitude': '0.528581', 'longitude': '35.7096', 'subdivision - eng': 'nan', 'discharge1Location - eng': 'nan', 'discharge_location': 'nan', 'tributariesLeft - eng': 'nan', 'tributariesleft': 'nan', 'tributariesRight - eng': 'nan', 'tributariesright': 'nan', 'othernames - eng': 'nan', 'othernames': 'nan', 'source - eng': 'nan', 'source': 'nan', 'discharge2Location - eng': 'nan', 'discharge2Location': 'nan', 'thumbnail - eng': 'KerioRiver-Flowing.jpg?width=300', 'wikiPageWikiLink - eng': 'Equator, List of rivers of Africa, Kenya, Kerio Valley, Elgeyo Escarpment, Lokichar River, Tugen Hills, Kerio Valley National Reserve, South Turkana National Reserve, Biretwo, Turkana County, Turkana people, Lake Turkana, Turkwel River', 'dbpedia_link': 'http://dbpedia.org/resource/Kerio_River', 'wikipedia_link': 'https://en.wikipedia.org/wiki/Kerio_River', 'river name - eng': '  Kerio   ', 'Country - eng': 'nan', 'country': 'nan', 'State - eng': 'nan', 'states': 'nan', 'Region - eng': 'nan', 'region': 'nan', 'Basin size - eng': 'nan', 'basinsize': 'nan', 'Source-elevation - eng': 'nan', 'sourceelevation': 'nan', 'Discharge-average - eng': 'nan', 'discharge_average': 'nan', 'Discharge-minimum - eng': 'nan', 'discharge_min': 'nan', 'Discharge-maximum - eng': 'nan', 'discharge_max': 'nan', 'Mouth-elevation - eng': 'nan', 'mouthelevation': 'nan', 'map': 'nan', 'Image_url': 'nan'}
#
#
#
#
#
# {{Infobox river
# | name = కెరియో
# }}
#
# ==భౌగోళిక ప్రదేశం(ప్రాంతం)==
#
# ఈ నది అక్షాంశం(లాటిట్యూడ్) 0.528581, రేఖాంశం(లాంగిట్యూడ్) 35.7096.<ref name="dbpedia_link">{{Cite web|url=http://dbpedia.org/resource/Kerio_River|title=About: |last=|first=|date=|website=dbpedia.org|url-status=live|archive-url=|archive-date=|access-date=2022-06-24}}</ref>
# ==మూలాలు==
# <references />
#
# [[వర్గం:నదులు]][[వర్గం:https://en.wikipedia.org/wiki/Kerio_Riverనదులు]]
#  [[వర్గం:http://dbpedia.org/resource/Kerio_Riverనదులు]]
#
#
# [[వర్గం:తెవికీ నదులు]]
#
#  87 కెరియో
# {'river_name': 'Irtysh', 'rivername': 'ఇర్తీష్', 'length': '4248.0', 'mouthplace - eng': 'nan', 'mouthplace': 'nan', 'rivermouth - eng': 'Ob (river)', 'mouth': 'ఓబ్ (నది)', 'mouthlocation - eng': 'nan', 'mouthlocation': 'nan', 'source1Location - eng': 'near Mang-tai-ch’ia-ta-fan pass, Altai Mountains, Xinjiang, China', 'source1location': 'మాంగ్-తాయ్-చియా-టా-ఫ్యాన్ పాస్ సమీపంలో, ఆల్టై పర్వతాలు, జిన్\u200cజియాంగ్, చైనా', 'geometry - eng': 'POINT(89.970001220703 47.877498626709)', 'latitude': '47.8775', 'longitude': '89.97', 'subdivision - eng': 'Russia, Kazakhstan, China, Mongolia', 'discharge1Location - eng': 'nan', 'discharge_location': 'nan', 'tributariesLeft - eng': 'nan', 'tributariesleft': 'nan', 'tributariesRight - eng': 'nan', 'tributariesright': 'nan', 'othernames - eng': 'nan', 'othernames': 'nan', 'source - eng': 'nan', 'source': 'nan', 'discharge2Location - eng': 'nan', 'discharge2Location': 'nan', 'thumbnail - eng': 'Irtysh river basin map.png?width=300', 'wikiPageWikiLink - eng': 'Fuyun County, China, Kalzhyr, Semey, Conquest of the Khanate of Sibir, Shulbinsk Hydroelectric Power Plant, Geography of China, Tyumen, Altai Town, Bukhtarma, Inland port, Xiaoerjing, Cherlak, File:Omsk 60 years of Victory bridge 2.jpg, Kuytun–Beitun railway, Ob (river), Omsk, Fyodor Dostoevsky, Project 635 Dam, Pavlodar, Uy (Irtysh), Tacheng, Khan (title), Dam, Cargo ship, Qashliq, Demyanka, Chinese language, File:Gorskii 04668u.jpg, Taiga, Surgut, Treaty of Saint Petersburg (1881), Uzbekistan, Petropavl, Oskemen Hydroelectric Power Plant, Ulungur River, File:Irtysh from air over Omsk.JPG, Kurshim, West Siberian Plain, Hydroelectricity, Haba River Shankou Dam, Dungan Revolt (1862–1877), Great Soviet Encyclopedia, Ulungur Lake, Khanate of Sibir, FC Irtysh Pavlodar, Crime and Punishment, Battle of Irtysh River, Siberian Cossacks, Interbasin transfer, Burqin (river), Serebryansk, Bering Strait, Tobol, Nur-Sultan, Ten Great Campaigns, File:Irtish v Omsk.JPG, Geography of Russia, Ashina Helu, Trans-Siberian Railway, Ishim (river), Altai Mountains, Jilebulake Dam, Tang campaigns against the Western Turks, Peter the Great, Amban, Aksu, Kazakhstan, Uba (river), Om (river), Tara, Omsk Oblast, Siberian Tatar language, Kazakhstan, Irtysh–Karamay–urumqi Canal, Endorheic basin, Altay City, The Gulag Archipelago, Beitun, Xinjiang, Western Turkic Khaganate, Xinjiang, Turkestan–Siberia Railway, Burqin River, Pinyin, Barnaul, Naryn (Irtysh), Orenburg, Mongols, Drainage basin, FC Irtysh Omsk, River, Asia, Dzungaria, Chagan (Irtysh), Ivan Neplyuyev, Su Dingfang, Kelan River, Lock (water navigation), Burqin Shankou Dam, Konda (river), Tobolsk, File:Pavlodar-Fiume Irtysh.JPG, Russia, Convention of Peking, Steppe, Geography of Kazakhstan, Dzungar Khanate, Tanker (ship), Oirats, Mongolia, Burqin County, Bukhtarma Hydroelectric Power Plant, Qing dynasty, Lake Zaysan, Tara (Irtysh), Osha (river), Haba River, Ulba, Tang dynasty, Northern river reversal, File:Operational Navigation Chart D-5, 6th edition.jpg, Shish (river), Khanty-Mansiysk, Zuo Zongtang, Karaganda, Turkic peoples, Irtysh–Karaganda Canal, Noska, Chonghuer Dam, Oskemen, File:Irtysh River landscape in the Burqin 02.jpg', 'dbpedia_link': 'http://dbpedia.org/resource/Irtysh', 'wikipedia_link': 'https://en.wikipedia.org/wiki/Irtysh', 'river name - eng': '  Irtysh  ', 'Country - eng': '  Mongolia, China, Kazakhstan, Russia  ', 'country': 'మంగోలియా, చైనా, కజాఖ్స్తాన్, రష్యా', 'State - eng': 'nan', 'states': 'nan', 'Region - eng': 'nan', 'region': 'nan', 'Basin size - eng': '  1,643,000 km2 (634,000 sq mi)  ', 'basinsize': '1,643,000 చదరపు కిలోమీటర్లు (634,000 చదరపు మైళ్ళు)', 'Source-elevation - eng': '  2,960 m (9,710 ft)  ', 'sourceelevation': '2,960 మీటర్లు (9,710 అడుగులు)', 'Discharge-average - eng': '  2,150 m3/s (76,000 cu ft/s) (near Tobolsk)  ', 'discharge_average': '2,150 ఘనపు మీటర్/సెకండ్ (76,000 ఘనపు అడుగులు/సెకండ్)', 'Discharge-minimum - eng': 'nan', 'discharge_min': 'nan', 'Discharge-maximum  ...
#
#
#
#
#
# {{Infobox river
# | name = ఇర్తీష్
# | subdivision_type1  = దేశం
# | subdivision_name1  = మంగోలియా, చైనా, కజాఖ్స్తాన్, రష్యా
# | length=4248.0 కి.మీ.
# | discharge1_avg = 2,150 ఘనపు మీటర్/సెకండ్ (76,000 ఘనపు అడుగులు/సెకండ్)
# | source1_location = మాంగ్-తాయ్-చియా-టా-ఫ్యాన్ పాస్ సమీపంలో, ఆల్టై పర్వతాలు, జిన్‌జియాంగ్, చైనా
# | source1_elevation =2,960 మీటర్లు (9,710 అడుగులు) కి.మీ.
# | mouth= ఓబ్ (నది)
# | basin_size = 1,643,000 చదరపు కిలోమీటర్లు (634,000 చదరపు మైళ్ళు)
# }}
#     ఇర్తీష్ నది [[మంగోలియా, చైనా, కజాఖ్స్తాన్, రష్యా]] దేశానికి చెందినది.ఇర్తీష్ నది పొడవు 4248.0 కిలోమీటర్లు. <ref name="wiki_link">{{Cite web|url=https://en.wikipedia.org/wiki/Irtysh|title=Irtysh|work=Wikipedia |language=en |access-date=2022-06-21}}</ref>
#
# ==భౌగోళిక ప్రదేశం(ప్రాంతం)==
#
# ఇర్తీష్ నది 1,643,000 చదరపు కిలోమీటర్లు (634,000 చదరపు మైళ్ళు) చదరపు కిలోమీటర్ల పరీవాహక ప్రాంతం కలిగి ఉంటుంది.<ref name="wiki_link" />ఈ నది అక్షాంశం(లాటిట్యూడ్) 47.8775, రేఖాంశం(లాంగిట్యూడ్) 89.97.<ref name="dbpedia_link">{{Cite web|url=http://dbpedia.org/resource/Irtysh|title=About: |last=|first=|date=|website=dbpedia.org|url-status=live|archive-url=|archive-date=|access-date=2022-06-24}}</ref>
#
# ==నది ప్రవాహం==
#
# ఇర్తీష్ నది [[మంగోలియా, చైనా, కజాఖ్స్తాన్, రష్యా]]లోని మాంగ్-తాయ్-చియా-టా-ఫ్యాన్ పాస్ సమీపంలో, ఆల్టై పర్వతాలు, జిన్‌జియాంగ్, చైనా దగ్గర మొదలవుతుంది.<ref name="dbpedia_link" />ఇర్తీష్ నది మూలం ఎత్తు 2,960 మీటర్లు (9,710 అడుగులు).<ref name="wiki_link" />ఇర్తీష్ నది [[ఓబ్ (నది)]]లో కలుస్తుంది. <ref name="dbpedia_link" />
#
# ==సముద్రంలో నీటి విడుదల==
#
# ఈ నది లోని నీరు క్షణముకు సగటు 2,150 ఘనపు మీటర్/సెకండ్ (76,000 ఘనపు అడుగులు/సెకండ్). <ref name="wiki_link" />
# ==మూలాలు==
# <references />
#
# [[వర్గం:నదులు]][[వర్గం:https://en.wikipedia.org/wiki/Irtyshనదులు]]
#  [[వర్గం:http://dbpedia.org/resource/Irtyshనదులు]]
#
#
# [[వర్గం:తెవికీ నదులు]]
#
#  88 ఇర్తీష్
# {'river_name': 'Volga', 'rivername': 'వొల్గా', 'length': '3531.0', 'mouthplace - eng': 'Astrakhan Oblast', 'mouthplace': 'ఆస్ట్రాఖాన్ ఒబ్లాస్ట్', 'rivermouth - eng': 'Caspian Sea', 'mouth': 'కాస్పియన్ సముద్రం', 'mouthlocation - eng': 'Astrakhan Oblast', 'mouthlocation': 'ఆస్ట్రాఖాన్ ఒబ్లాస్ట్', 'source1Location - eng': 'Tver Oblast, Valdai Hills', 'source1location': 'ట్వెర్ ఒబ్లాస్ట్, వాల్డై హిల్స్', 'geometry - eng': 'POINT(32.468082427979 57.251304626465)', 'latitude': '57.2513', 'longitude': '32.4681', 'subdivision - eng': 'Russia, Volgograd, Eastern Europe, Saratov, Ulyanovsk, Kazan, Tver, Cheboksary, Samara, Astrakhan, Yaroslavl, Nizhny Novgorod', 'discharge1Location - eng': 'Astrakhan', 'discharge_location': 'ఆస్ట్రాఖాన్', 'tributariesLeft - eng': 'Kama (river)', 'tributariesleft': 'కామ (నది)', 'tributariesRight - eng': 'Oka (river)', 'tributariesright': 'ఓకా (నది)', 'othernames - eng': 'nan', 'othernames': 'nan', 'source - eng': 'nan', 'source': 'nan', 'discharge2Location - eng': 'nan', 'discharge2Location': 'nan', 'thumbnail - eng': 'Yaroslavl. Volga River. Cathedral of the Dormition P5212700 2200.jpg?width=300', 'wikiPageWikiLink - eng': 'Steamboats on the Volga River, Nazi Germany, Moskva (river), Tvertsa, Persian language, Selizharovka, The Storm (Ostrovsky), Sogdian language, Forest steppe, Cargo, Isidor Annensky, Medveditsa (Volg, File:Soviet marines-in the battle of stalingrad volga banks.jpg, Kazanka (river), Saint Petersburg, Yegor Bulychov and Others, Kashinka, Grain, Volga trade route, Vyatichi, Astrakhan Khanate, Nerl (Volg, Dubna (Volg, Oka (river), Arab world, Sozh, In the Forests, Tributary, The Precipice (Goncharov novel), Ob (river), Election Day (2007 film), Balts, Volga Delta, Salt, Scythian languages, Pelican, Konakovo, Mologa, Black Sea, Moderate Resolution Imaging Spectroradiometer, Byzantine Empire, File:Вид на Девью гору с Молодецкого кургана.jpg, Balakhna, Caspian Sea, Caviar, Volgograd Reservoir, Russo-Kazan Wars, Saratov, Huns, List of battles by casualties, Lake Ladoga, Offensive (military), Pollution, Cheboksary, File:Саратовский мост.jpeg, Astrakhan, Scythians, Volsk, Without a Dowry, Shosha (river), Reservoir, Golden Horde, Orenburg Oblast, Metro Exodus, File:ISS-60 Volga River flowing into the Caspian Sea.jpg, Viking Age, Culture of Russia, Chuvash language, File:Utes step raz2.jpg, Kama (river), Volga Flotilla, Tver, Southern Russia, Samuil Marshak, Vedic Sanskrit, Hydronym, Meryans, Kuybyshev Reservoir, Selizharovo, Zubtsov, Czech language, Samara, Khazars, Grigori Aleksandrov, Rus Khaganate, Kerzhenets, Croatian language, White Sea, Estuary, Adolf Hitler, Russian literature, Rybinsk, Yaroslavl, Military, Serbian language, Height above sea level, Lake Onega, Eldar Ryazanov, Kimry, Ekaterina Voronina (film), Amphibious warfare, Volgotanker, Hydroelectricity, Kazan Operation, File:Ilia Efimovich Repin (1844-1930) - Volga Boatmen (1870-1873).jpg, Kozmodemyansk, Kievan Rus, Vesyegonsk, Bolshoy Irgiz, Volga Bulgaria, Central Russia, File:Rybinsk Reservoir. Cruise ship Maksim Litvinov P5213234 2200.jpg, Ivankovo Reservoir, Azerbaijan, Oil tanker, Nikolay Nekrasov, Stalemate, Caspian Depression, File:Volga River. Tolga Monastery P5212881 2200.jpg, Yuryevets, Ivanovo Oblast, Buzan (river), Sea of Azov, Folklore of Russia, Kostroma, File:Volga Hydroelectric Station 002 (cropped).JPG, Dubna, Iran, Kostroma (river), Alexandria, List of cities and towns in Russia by population, Saratov Reservoir, Potash, Moscow Canal, North Germanic peoples, Wikt:رگ, Sarmatians, Mordvins, Fortification, Catherine the Great, Rybinsk Reservoir, List of ancient Slavic peoples, List of rivers of Europe, Vazuza, Europe, Buzhans, European Russia, Kazan, Lake Sterzh, Sredniy Buzhan, Gun, Hyperborea, Volga Germans, Industrialisation, Volga Finns, Maxim Gorky, Nizhny Novgorod, Wheat, Muslims, Volgograd, Atil, Don (river), Russian Civil War, Turkish language, File:Staritsa.jpg, Battle of Stalingrad, File:Volgograd. River Sta ...
#
#
#
#
#
# {{Infobox river
# | name = వొల్గా
# | subdivision_type1  = దేశం
# | subdivision_name1  = రష్యన్ ఫెడరేషన్
# | length=3531.0 కి.మీ.
# | discharge1_location= ఆస్ట్రాఖాన్
# | discharge1_min= 5090 క్యూబిక్ మీటర్లు (180000 క్యూబిక్ అడుగులు)
# | discharge1_avg = 176 ఘనపు మీటర్/సెకండ్ (6,200 ఘనపు అడుగులు/సెకండ్)
# | discharge1_max = 48,450 క్యూబిక్ మీటర్లు (1,711,000 క్యూబిక్ అడుగులు)
# | source1_location = ట్వెర్ ఒబ్లాస్ట్, వాల్డై హిల్స్
# | source1_elevation =228 1మీటర్లు (748 అడుగులు) కి.మీ.
# | mouth= కాస్పియన్ సముద్రం
# | mouth_location = ఆస్ట్రాఖాన్ ఒబ్లాస్ట్
# | mouth_elevation =−28 1 మీటర్లు (−92 అడుగులు) కి.మీ.
# | basin_size = 1,360,000 చదరపు కిలోమీటర్లు (530,000 చదరపు మైళ్ళు)
# | tributaries_left = కామ (నది)
# | tributaries_right = ఓకా (నది)
# }}
#     వొల్గా నది [[రష్యన్ ఫెడరేషన్]] దేశమునకు చెందినది.ఈ నది పొడవు 3531.0కిలోమీటర్లు.<ref name="wiki_link">{{Cite web|url=https://en.wikipedia.org/wiki/Volga|title=Volga|work=Wikipedia |language=en |access-date=2022-06-21}}</ref>
#
# ==భౌగోళిక ప్రదేశం(ప్రాంతం)==
#
# వొల్గా నది పరీవాహక ప్రాంతం 1,360,000 చదరపు కిలోమీటర్లు (530,000 చదరపు మైళ్ళు) చదరపు కిలోమీటర్లు.<ref name="wiki_link" />ఈ నది అక్షాంశం(లాటిట్యూడ్) 57.2513, రేఖాంశం(లాంగిట్యూడ్) 32.4681.<ref name="dbpedia_link">{{Cite web|url=http://dbpedia.org/resource/Volga|title=About: |last=|first=|date=|website=dbpedia.org|url-status=live|archive-url=|archive-date=|access-date=2022-06-24}}</ref>
#
# ==నది ఉపనదులు==
#
# వొల్గా నది ఎడమ ఉపనదులు కామ (నది).వొల్గా నది కుడి ఉపనదులు ఓకా (నది).<ref name="dbpedia_link" />
#
# ==నది ప్రవాహం==
#
# [[రష్యన్ ఫెడరేషన్]]లోని ట్వెర్ ఒబ్లాస్ట్, వాల్డై హిల్స్ దగ్గర వొల్గా నది మొదలవుతుంది.<ref name="dbpedia_link" />ఈ నది మూలం ఎత్తు 228 1మీటర్లు (748 అడుగులు).<ref name="wiki_link" />ఈ నది ఆస్ట్రాఖాన్ ఒబ్లాస్ట్ దగ్గర [[కాస్పియన్ సముద్రం]]లో కలుస్తుంది.<ref name="dbpedia_link" />ఈ నది −28 1 మీటర్లు (−92 అడుగులు) ఎత్తునుంచి సముద్రంలో కలుస్తుంది.<ref name="wiki_link" />
#
# ==సముద్రంలో నీటి విడుదల==
#
# వొల్గా నది ఆస్ట్రాఖాన్ వద్ద సముద్రంలో కలుస్తుంది.<ref name="dbpedia_link" />వొల్గా నది లోని నీరు క్షణముకు సగటు 176 ఘనపు మీటర్/సెకండ్ (6,200 ఘనపు అడుగులు/సెకండ్).<ref name="wiki_link" /> ఇప్పటి వరకు నమోదు అయినా రికార్డుల ప్రకారం వొల్గా నది లోని నీరు క్షణముకు గరిష్ట మోతాదు 48,450 క్యూబిక్ మీటర్లు (1,711,000 క్యూబిక్ అడుగులు).<ref name="wiki_link" />ఇప్పటి వరకు నమోదు అయినా కనిష్ట మోతాదు క్షణముకు 5090 క్యూబిక్ మీటర్లు (180000 క్యూబిక్ అడుగులు).<ref name="wiki_link" />
# ==మూలాలు==
# <references />
#
# [[వర్గం:నదులు]][[వర్గం:https://en.wikipedia.org/wiki/Volgaనదులు]]
#  [[వర్గం:http://dbpedia.org/resource/Volgaనదులు]]
#
#
# [[వర్గం:తెవికీ నదులు]]
#
#  89 వొల్గా
# ...
#
#
#
#
#
# {{Infobox river
# }}
# ==మూలాలు==
# <references />
#
# [[వర్గం:నదులు]]
#
#
#
# [[వర్గం:తెవికీ నదులు]]
#
#  28925 nan
# {'river_name': 'nan', 'rivername': 'nan', 'length': 'nan', 'mouthplace - eng': 'nan', 'mouthplace': 'nan', 'rivermouth - eng': 'nan', 'mouth': 'nan', 'mouthlocation - eng': 'nan', 'mouthlocation': 'nan', 'source1Location - eng': 'nan', 'source1location': 'nan', 'geometry - eng': 'nan', 'latitude': 'nan', 'longitude': 'nan', 'subdivision - eng': 'nan', 'discharge1Location - eng': 'nan', 'discharge_location': 'nan', 'tributariesLeft - eng': 'nan', 'tributariesleft': 'nan', 'tributariesRight - eng': 'nan', 'tributariesright': 'nan', 'othernames - eng': 'nan', 'othernames': 'nan', 'source - eng': 'nan', 'source': 'nan', 'discharge2Location - eng': 'nan', 'discharge2Location': 'nan', 'thumbnail - eng': 'nan', 'wikiPageWikiLink - eng': 'nan', 'dbpedia_link': 'nan', 'wikipedia_link': 'nan', 'river name - eng': 'nan', 'Country - eng': 'nan', 'country': 'nan', 'State - eng': 'nan', 'states': 'nan', 'Region - eng': 'nan', 'region': 'nan', 'Basin size - eng': 'nan', 'basinsize': 'nan', 'Source-elevation - eng': 'nan', 'sourceelevation': 'nan', 'Discharge-average - eng': 'nan', 'discharge_average': 'nan', 'Discharge-minimum - eng': 'nan', 'discharge_min': 'nan', 'Discharge-maximum - eng': 'nan', 'discharge_max': 'nan', 'Mouth-elevation - eng': 'nan', 'mouthelevation': 'nan', 'map': 'nan', 'Image_url': 'nan'}
#
#
#
#
#
# {{Infobox river
# }}
# ==మూలాలు==
# <references />
#
# [[వర్గం:నదులు]]
#
#
#
# [[వర్గం:తెవికీ నదులు]]
#
#  28926 nan
# {'river_name': 'nan', 'rivername': 'nan', 'length': 'nan', 'mouthplace - eng': 'nan', 'mouthplace': 'nan', 'rivermouth - eng': 'nan', 'mouth': 'nan', 'mouthlocation - eng': 'nan', 'mouthlocation': 'nan', 'source1Location - eng': 'nan', 'source1location': 'nan', 'geometry - eng': 'nan', 'latitude': 'nan', 'longitude': 'nan', 'subdivision - eng': 'nan', 'discharge1Location - eng': 'nan', 'discharge_location': 'nan', 'tributariesLeft - eng': 'nan', 'tributariesleft': 'nan', 'tributariesRight - eng': 'nan', 'tributariesright': 'nan', 'othernames - eng': 'nan', 'othernames': 'nan', 'source - eng': 'nan', 'source': 'nan', 'discharge2Location - eng': 'nan', 'discharge2Location': 'nan', 'thumbnail - eng': 'nan', 'wikiPageWikiLink - eng': 'nan', 'dbpedia_link': 'nan', 'wikipedia_link': 'nan', 'river name - eng': 'nan', 'Country - eng': 'nan', 'country': 'nan', 'State - eng': 'nan', 'states': 'nan', 'Region - eng': 'nan', 'region': 'nan', 'Basin size - eng': 'nan', 'basinsize': 'nan', 'Source-elevation - eng': 'nan', 'sourceelevation': 'nan', 'Discharge-average - eng': 'nan', 'discharge_average': 'nan', 'Discharge-minimum - eng': 'nan', 'discharge_min': 'nan', 'Discharge-maximum - eng': 'nan', 'discharge_max': 'nan', 'Mouth-elevation - eng': 'nan', 'mouthelevation': 'nan', 'map': 'Relief_Yakutia.png', 'Image_url': 'nan'}
#
#
#
#
#
# {{Infobox river
# | map = Relief_Yakutia.png
# | map_size = 300 px
# | map_caption = nan నది పటం
# }}
# ==మూలాలు==
# <references />
#
# [[వర్గం:నదులు]]
#
#
#
# [[వర్గం:తెవికీ నదులు]]
#
#  28927 nan
# {'river_name': 'nan', 'rivername': 'nan', 'length': 'nan', 'mouthplace - eng': 'nan', 'mouthplace': 'nan', 'rivermouth - eng': 'nan', 'mouth': 'nan', 'mouthlocation - eng': 'nan', 'mouthlocation': 'nan', 'source1Location - eng': 'nan', 'source1location': 'nan', 'geometry - eng': 'nan', 'latitude': 'nan', 'longitude': 'nan', 'subdivision - eng': 'nan', 'discharge1Location - eng': 'nan', 'discharge_location': 'nan', 'tributariesLeft - eng': 'nan', 'tributariesleft': 'nan', 'tributariesRight - eng': 'nan', 'tributariesright': 'nan', 'othernames - eng': 'nan', 'othernames': 'nan', 'source - eng': 'nan', 'source': 'nan', 'discharge2Location - eng': 'nan', 'discharge2Location': 'nan', 'thumbnail - eng': 'nan', 'wikiPageWikiLink - eng': 'nan', 'dbpedia_link': 'nan', 'wikipedia_link': 'nan', 'river name - eng': 'nan', 'Country - eng': 'nan', 'country': 'nan', 'State - eng': 'nan', 'states': 'nan', 'Region - eng': 'nan', 'region': 'nan', 'Basin size - eng': 'nan', 'basinsize': 'nan', 'Source-elevation - eng': 'nan', 'sourceelevation': 'nan', 'Discharge-average - eng': 'nan', 'discharge_average': 'nan', 'Discharge-minimum - eng': 'nan', 'discharge_min': 'nan', 'Discharge-maximum - eng': 'nan', 'discharge_max': 'nan', 'Mouth-elevation - eng': 'nan', 'mouthelevation': 'nan', 'map': 'Relief_Yakutia.png', 'Image_url': 'nan'}
#
#
#
#
#
# {{Infobox river
# | map = Relief_Yakutia.png
# | map_size = 300 px
# | map_caption = nan నది పటం
# }}
# ==మూలాలు==
# <references />
#
# [[వర్గం:నదులు]]
#
#
#
# [[వర్గం:తెవికీ నదులు]]
#
#  28928 nan
# {'river_name': 'nan', 'rivername': 'nan', 'length': 'nan', 'mouthplace - eng': 'nan', 'mouthplace': 'nan', 'rivermouth - eng': 'nan', 'mouth': 'nan', 'mouthlocation - eng': 'nan', 'mouthlocation': 'nan', 'source1Location - eng': 'nan', 'source1location': 'nan', 'geometry - eng': 'nan', 'latitude': 'nan', 'longitude': 'nan', 'subdivision - eng': 'nan', 'discharge1Location - eng': 'nan', 'discharge_location': 'nan', 'tributariesLeft - eng': 'nan', 'tributariesleft': 'nan', 'tributariesRight - eng': 'nan', 'tributariesright': 'nan', 'othernames - eng': 'nan', 'othernames': 'nan', 'source - eng': 'nan', 'source': 'nan', 'discharge2Location - eng': 'nan', 'discharge2Location': 'nan', 'thumbnail - eng': 'nan', 'wikiPageWikiLink - eng': 'nan', 'dbpedia_link': 'nan', 'wikipedia_link': 'nan', 'river name - eng': 'nan', 'Country - eng': 'nan', 'country': 'nan', 'State - eng': 'nan', 'states': 'nan', 'Region - eng': 'nan', 'region': 'nan', 'Basin size - eng': 'nan', 'basinsize': 'nan', 'Source-elevation - eng': 'nan', 'sourceelevation': 'nan', 'Discharge-average - eng': 'nan', 'discharge_average': 'nan', 'Discharge-minimum - eng': 'nan', 'discharge_min': 'nan', 'Discharge-maximum - eng': 'nan', 'discharge_max': 'nan', 'Mouth-elevation - eng': 'nan', 'mouthelevation': 'nan', 'map': 'Relief_Yakutia.png', 'Image_url': 'nan'}
#
#
#
#
#
# {{Infobox river
# | map = Relief_Yakutia.png
# | map_size = 300 px
# | map_caption = nan నది పటం
# }}
# ==మూలాలు==
# <references />
#
# [[వర్గం:నదులు]]
#
#
#
# [[వర్గం:తెవికీ నదులు]]
#
#  28929 nan
# {'river_name': 'nan', 'rivername': 'nan', 'length': 'nan', 'mouthplace - eng': 'nan', 'mouthplace': 'nan', 'rivermouth - eng': 'nan', 'mouth': 'nan', 'mouthlocation - eng': 'nan', 'mouthlocation': 'nan', 'source1Location - eng': 'nan', 'source1location': 'nan', 'geometry - eng': 'nan', 'latitude': 'nan', 'longitude': 'nan', 'subdivision - eng': 'nan', 'discharge1Location - eng': 'nan', 'discharge_location': 'nan', 'tributariesLeft - eng': 'nan', 'tributariesleft': 'nan', 'tributariesRight - eng': 'nan', 'tributariesright': 'nan', 'othernames - eng': 'nan', 'othernames': 'nan', 'source - eng': 'nan', 'source': 'nan', 'discharge2Location - eng': 'nan', 'discharge2Location': 'nan', 'thumbnail - eng': 'nan', 'wikiPageWikiLink - eng': 'nan', 'dbpedia_link': 'nan', 'wikipedia_link': 'nan', 'river name - eng': 'nan', 'Country - eng': 'nan', 'country': 'nan', 'State - eng': 'nan', 'states': 'nan', 'Region - eng': 'nan', 'region': 'nan', 'Basin size - eng': 'nan', 'basinsize': 'nan', 'Source-elevation - eng': 'nan', 'sourceelevation': 'nan', 'Discharge-average - eng': 'nan', 'discharge_average': 'nan', 'Discharge-minimum - eng': 'nan', 'discharge_min': 'nan', 'Discharge-maximum - eng': 'nan', 'discharge_max': 'nan', 'Mouth-elevation - eng': 'nan', 'mouthelevation': 'nan', 'map': 'Relief_Yakutia.png', 'Image_url': 'nan'}
#
#
#
#
#
# {{Infobox river
# | map = Relief_Yakutia.png
# | map_size = 300 px
# | map_caption = nan నది పటం
# }}
# ==మూలాలు==
# <references />
#
# [[వర్గం:నదులు]]
#
#
#
# [[వర్గం:తెవికీ నదులు]]
#
#  28930 nan
# {'river_name': 'nan', 'rivername': 'nan', 'length': 'nan', 'mouthplace - eng': 'nan', 'mouthplace': 'nan', 'rivermouth - eng': 'nan', 'mouth': 'nan', 'mouthlocation - eng': 'nan', 'mouthlocation': 'nan', 'source1Location - eng': 'nan', 'source1location': 'nan', 'geometry - eng': 'nan', 'latitude': 'nan', 'longitude': 'nan', 'subdivision - eng': 'nan', 'discharge1Location - eng': 'nan', 'discharge_location': 'nan', 'tributariesLeft - eng': 'nan', 'tributariesleft': 'nan', 'tributariesRight - eng': 'nan', 'tributariesright': 'nan', 'othernames - eng': 'nan', 'othernames': 'nan', 'source - eng': 'nan', 'source': 'nan', 'discharge2Location - eng': 'nan', 'discharge2Location': 'nan', 'thumbnail - eng': 'nan', 'wikiPageWikiLink - eng': 'nan', 'dbpedia_link': 'nan', 'wikipedia_link': 'nan', 'river name - eng': 'nan', 'Country - eng': 'nan', 'country': 'nan', 'State - eng': 'nan', 'states': 'nan', 'Region - eng': 'nan', 'region': 'nan', 'Basin size - eng': 'nan', 'basinsize': 'nan', 'Source-elevation - eng': 'nan', 'sourceelevation': 'nan', 'Discharge-average - eng': 'nan', 'discharge_average': 'nan', 'Discharge-minimum - eng': 'nan', 'discharge_min': 'nan', 'Discharge-maximum - eng': 'nan', 'discharge_max': 'nan', 'Mouth-elevation - eng': 'nan', 'mouthelevation': 'nan', 'map': 'Relief_Yakutia.png', 'Image_url': 'nan'}
#
#
#
#
#
# {{Infobox river
# | map = Relief_Yakutia.png
# | map_size = 300 px
# | map_caption = nan నది పటం
# }}
# ==మూలాలు==
# <references />
#
# [[వర్గం:నదులు]]
#
#
#
# [[వర్గం:తెవికీ నదులు]]
#
#  28931 nan
# {'river_name': 'nan', 'rivername': 'nan', 'length': 'nan', 'mouthplace - eng': 'nan', 'mouthplace': 'nan', 'rivermouth - eng': 'nan', 'mouth': 'nan', 'mouthlocation - eng': 'nan', 'mouthlocation': 'nan', 'source1Location - eng': 'nan', 'source1location': 'nan', 'geometry - eng': 'nan', 'latitude': 'nan', 'longitude': 'nan', 'subdivision - eng': 'nan', 'discharge1Location - eng': 'nan', 'discharge_location': 'nan', 'tributariesLeft - eng': 'nan', 'tributariesleft': 'nan', 'tributariesRight - eng': 'nan', 'tributariesright': 'nan', 'othernames - eng': 'nan', 'othernames': 'nan', 'source - eng': 'nan', 'source': 'nan', 'discharge2Location - eng': 'nan', 'discharge2Location': 'nan', 'thumbnail - eng': 'nan', 'wikiPageWikiLink - eng': 'nan', 'dbpedia_link': 'nan', 'wikipedia_link': 'nan', 'river name - eng': 'nan', 'Country - eng': 'nan', 'country': 'nan', 'State - eng': 'nan', 'states': 'nan', 'Region - eng': 'nan', 'region': 'nan', 'Basin size - eng': 'nan', 'basinsize': 'nan', 'Source-elevation - eng': 'nan', 'sourceelevation': 'nan', 'Discharge-average - eng': 'nan', 'discharge_average': 'nan', 'Discharge-minimum - eng': 'nan', 'discharge_min': 'nan', 'Discharge-maximum - eng': 'nan', 'discharge_max': 'nan', 'Mouth-elevation - eng': 'nan', 'mouthelevation': 'nan', 'map': 'Relief_Yakutia.png', 'Image_url': 'nan'}
#
#
#
#
#
# {{Infobox river
# | map = Relief_Yakutia.png
# | map_size = 300 px
# | map_caption = nan నది పటం
# }}
# ==మూలాలు==
# <references />
#
# [[వర్గం:నదులు]]
#
#
#
# [[వర్గం:తెవికీ నదులు]]
#
#  28932 nan
# {'river_name': 'nan', 'rivername': 'nan', 'length': 'nan', 'mouthplace - eng': 'nan', 'mouthplace': 'nan', 'rivermouth - eng': 'nan', 'mouth': 'nan', 'mouthlocation - eng': 'nan', 'mouthlocation': 'nan', 'source1Location - eng': 'nan', 'source1location': 'nan', 'geometry - eng': 'nan', 'latitude': 'nan', 'longitude': 'nan', 'subdivision - eng': 'nan', 'discharge1Location - eng': 'nan', 'discharge_location': 'nan', 'tributariesLeft - eng': 'nan', 'tributariesleft': 'nan', 'tributariesRight - eng': 'nan', 'tributariesright': 'nan', 'othernames - eng': 'nan', 'othernames': 'nan', 'source - eng': 'nan', 'source': 'nan', 'discharge2Location - eng': 'nan', 'discharge2Location': 'nan', 'thumbnail - eng': 'nan', 'wikiPageWikiLink - eng': 'nan', 'dbpedia_link': 'nan', 'wikipedia_link': 'nan', 'river name - eng': 'nan', 'Country - eng': 'nan', 'country': 'nan', 'State - eng': 'nan', 'states': 'nan', 'Region - eng': 'nan', 'region': 'nan', 'Basin size - eng': 'nan', 'basinsize': 'nan', 'Source-elevation - eng': 'nan', 'sourceelevation': 'nan', 'Discharge-average - eng': 'nan', 'discharge_average': 'nan', 'Discharge-minimum - eng': 'nan', 'discharge_min': 'nan', 'Discharge-maximum - eng': 'nan', 'discharge_max': 'nan', 'Mouth-elevation - eng': 'nan', 'mouthelevation': 'nan', 'map': 'France_relief_location_map.jpg', 'Image_url': 'nan'}
#
#
#
#
#
# {{Infobox river
# | map = France_relief_location_map.jpg
# | map_size = 300 px
# | map_caption = nan నది పటం
# }}
# ==మూలాలు==
# <references />
#
# [[వర్గం:నదులు]]
#
#
#
# [[వర్గం:తెవికీ నదులు]]
#
#  28933 nan
# {'river_name': 'nan', 'rivername': 'nan', 'length': 'nan', 'mouthplace - eng': 'nan', 'mouthplace': 'nan', 'rivermouth - eng': 'nan', 'mouth': 'nan', 'mouthlocation - eng': 'nan', 'mouthlocation': 'nan', 'source1Location - eng': 'nan', 'source1location': 'nan', 'geometry - eng': 'nan', 'latitude': 'nan', 'longitude': 'nan', 'subdivision - eng': 'nan', 'discharge1Location - eng': 'nan', 'discharge_location': 'nan', 'tributariesLeft - eng': 'nan', 'tributariesleft': 'nan', 'tributariesRight - eng': 'nan', 'tributariesright': 'nan', 'othernames - eng': 'nan', 'othernames': 'nan', 'source - eng': 'nan', 'source': 'nan', 'discharge2Location - eng': 'nan', 'discharge2Location': 'nan', 'thumbnail - eng': 'nan', 'wikiPageWikiLink - eng': 'nan', 'dbpedia_link': 'nan', 'wikipedia_link': 'nan', 'river name - eng': 'nan', 'Country - eng': 'nan', 'country': 'nan', 'State - eng': 'nan', 'states': 'nan', 'Region - eng': 'nan', 'region': 'nan', 'Basin size - eng': 'nan', 'basinsize': 'nan', 'Source-elevation - eng': 'nan', 'sourceelevation': 'nan', 'Discharge-average - eng': 'nan', 'discharge_average': 'nan', 'Discharge-minimum - eng': 'nan', 'discharge_min': 'nan', 'Discharge-maximum - eng': 'nan', 'discharge_max': 'nan', 'Mouth-elevation - eng': 'nan', 'mouthelevation': 'nan', 'map': 'nan', 'Image_url': 'nan'}
#
#
#
#
#
# {{Infobox river
# }}
# ==మూలాలు==
# <references />
#
# [[వర్గం:నదులు]]
#
#
#
# [[వర్గం:తెవికీ నదులు]]
#
#  28934 nan
# {'river_name': 'nan', 'rivername': 'nan', 'length': 'nan', 'mouthplace - eng': 'nan', 'mouthplace': 'nan', 'rivermouth - eng': 'nan', 'mouth': 'nan', 'mouthlocation - eng': 'nan', 'mouthlocation': 'nan', 'source1Location - eng': 'nan', 'source1location': 'nan', 'geometry - eng': 'nan', 'latitude': 'nan', 'longitude': 'nan', 'subdivision - eng': 'nan', 'discharge1Location - eng': 'nan', 'discharge_location': 'nan', 'tributariesLeft - eng': 'nan', 'tributariesleft': 'nan', 'tributariesRight - eng': 'nan', 'tributariesright': 'nan', 'othernames - eng': 'nan', 'othernames': 'nan', 'source - eng': 'nan', 'source': 'nan', 'discharge2Location - eng': 'nan', 'discharge2Location': 'nan', 'thumbnail - eng': 'nan', 'wikiPageWikiLink - eng': 'nan', 'dbpedia_link': 'nan', 'wikipedia_link': 'nan', 'river name - eng': 'nan', 'Country - eng': 'nan', 'country': 'nan', 'State - eng': 'nan', 'states': 'nan', 'Region - eng': 'nan', 'region': 'nan', 'Basin size - eng': 'nan', 'basinsize': 'nan', 'Source-elevation - eng': 'nan', 'sourceelevation': 'nan', 'Discharge-average - eng': 'nan', 'discharge_average': 'nan', 'Discharge-minimum - eng': 'nan', 'discharge_min': 'nan', 'Discharge-maximum - eng': 'nan', 'discharge_max': 'nan', 'Mouth-elevation - eng': 'nan', 'mouthelevation': 'nan', 'map': 'Relief_Yakutia.png', 'Image_url': 'nan'}
#
#
#
#
#
# {{Infobox river
# | map = Relief_Yakutia.png
# | map_size = 300 px
# | map_caption = nan నది పటం
# }}
# ==మూలాలు==
# <references />
#
# [[వర్గం:నదులు]]
#
#
#
# [[వర్గం:తెవికీ నదులు]]
#
#  28935 nan

# %%
for i, Id in enumerate(ids):
  row = data.loc[data['rivername']==Id]
  title = row['rivername'].values[0]
  text =template.render(getData(row))
  print(text)
  writePage(title, text, fobj)
  print('\n', i, title)

fobj.write('</mediawiki>')
fobj.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-74f591979e02> in <module>()
# ----> 1 for i, Id in enumerate(ids):
#       2   row = data.loc[data['rivername']==Id]
#       3   title = row['rivername'].values[0]
#       4   text =template.render(getData(row))
#       5   print(text)
#
# NameError: name 'ids' is not defined
